# %% [markdown]
# # This notebook show all indexed videos information

# %%
import os, sys, pandas as pd

# Import library with current code functions
sys.path.append(os.path.join("..", "lib"))
import general_functions as gf, files_paths as fp

# %% [markdown]
# ## Search all Dataset VD_INFO files

# %%
VD_INFO_LIST = gf.find_files_in_all_subdirectories([fp.DATASET_LOCAL, fp.DATASET_YT], fp.VD_INFO)
VIDEO_INDEX_DTFRAME = pd.DataFrame()

# %% [markdown]
# ## Concatenate all the VD_INFOS information

# %%
for current_path_location in VD_INFO_LIST:
    video_info = gf.READ_CSV_FILE(current_path_location)

    video_feature = gf.READ_CSV_FILE(os.path.dirname(current_path_location), fp.VD_FEATURES_L1)
    
    # Count instances in each video
    video_info['total_instance'] = video_feature['instance_ref'].nunique()
    
    # Mount index dataframe
    VIDEO_INDEX_DTFRAME = pd.concat([VIDEO_INDEX_DTFRAME, video_info], axis=0, ignore_index=True)

# %% [markdown]
# ## Show the number of each origin video

# %%
print('Total DD-Local Videos:', len(VIDEO_INDEX_DTFRAME.query("origin_vid == 'D'")))
print('Total YT-Online Videos:', len(VIDEO_INDEX_DTFRAME.query("origin_vid == 'Y'")))
# Out:
# Total DD-Local Videos: 21
# Total YT-Online Videos: 0

# %% [markdown]
# ## Show information for all LOCAL VIDEOS

# %%
VIDEO_INDEX_DTFRAME.query("origin_vid == 'D'")
# Out:
#     video_id origin_vid process_status          link_video  height_vid  \
# 0          1          D              L  video_mandela_crop         720
# 1          2          D              L         295xopXuU5E         720
# 2          3          D              L         2q_eNp4mDGU         720
# 3          4          D              L         4W09LPCCJ4U         720
# 4          5          D              L         5KY8V6HBAro         720
# 5          6          D              L         61gzN0c9K3g         720
# 6          7          D              L         6koC82XF9bc         720
# 7          8          D              L         8hDfY5JR4Ic         720
# 8          9          D              L         AjHji_Ff4Mc         720
# 9         10          D              L         H9HzZV6pW7g         720
# 10        11          D              L         JrdZ63GIL8k         720
# 11        12          D              L         Ka19xzJ_DQw         720
# 12        13          D              L         Kfp0e9qlVyc         720
# 13        14          D              L         MwHKnkuzM3c         720
# 14        15          D              L         SBVFwCGW8_A         720
# 15        16          D              L         WUs_B1G4564         720
# 16        17          D              L         caX-uN1uCqY         720
# 17        18          D              L         hBdjcicU78E         720
# 18        19          D              L         p9cvrKEFUhc         720
# 19        20          D              L         rL3MTusPLu4         720
# 20        21          D              L         zKoqa_MyYtw         720
#
#     width_vid  duration_vid   fps_vid  total_frames  time_step_fr  \
# 0        1280          3.36  29.97003           100      0.033367
# 1        1280         89.30  29.97003          2676      0.033367
# 2        1280         83.68  29.97003          2507      0.033367
# 3        1280         79.90  29.97003          2394      0.033367
# 4        1280        213.28  30.00000          6398      0.033333
# 5        1280        142.78  29.97003          4279      0.033367
# 6        1280        174.08  29.97003          5217      0.033367
# 7        1280        146.15  29.97003          4380      0.033367
# 8        1280        140.92  29.97003          4223      0.033367
# 9        1280        273.95  30.00000          8218      0.033333
# 10       1280         92.23  29.97003          2764      0.033367
# 11       1280        161.22  29.97003          4831      0.033367
# 12       1280        101.84  29.97003          3052      0.033367
# 13       1280        298.54  30.00000          8956      0.033333
# 14       1280         73.07  29.97003          2189      0.033367
# 15       1280        222.40  29.97003          6665      0.033367
# 16       1280        212.02  29.97003          6354      0.033367
# 17       1280         52.36  29.97003          1569      0.033367
# 18       1280         91.58  29.97003          2744      0.033367
# 19       1280        174.54  29.97003          5230      0.033367
# 20       1280        172.22  29.97003          5161      0.033367
#
#     total_instance
# 0                1
# 1                3
# 2                3
# 3                3
# 4                1
# 5                3
# 6                3
# 7                3
# 8                3
# 9                1
# 10               2
# 11               3
# 12               3
# 13               2
# 14               3
# 15               2
# 16               2
# 17               1
# 18               3
# 19               3
# 20               1

# %% [markdown]
# ## Show information for all Youtube VIDEOS

# %%
VIDEO_INDEX_DTFRAME.query("origin_vid == 'Y'")
# Out:
# Empty DataFrame
# Columns: [video_id, origin_vid, process_status, link_video, height_vid, width_vid, duration_vid, fps_vid, total_frames, time_step_fr, total_instance]
# Index: []

# %% [markdown]
# # This notebook show all indexed videos information

# %%
import os
import sys
import pandas as pd

# Import library with current code functions
sys.path.append(os.path.join("..", "lib"))
import general_functions as gf, files_paths as fp

# %% [markdown]
# ## Search all Dataset VD_INFO files

# %%
VD_INFO_LIST = gf.find_files_in_all_subdirectories([fp.DATASET_LOCAL, fp.DATASET_YT], fp.VD_INFO)
VIDEO_INDEX_DTFRAME = pd.DataFrame()

# %% [markdown]
# ## Concatenate all the VD_INFOS information

# %%
for current_path_location in VD_INFO_LIST:
    video_info = gf.READ_CSV_FILE(current_path_location)

    video_feature = gf.READ_CSV_FILE(os.path.dirname(current_path_location), fp.VD_FEATURES_L1)
    
    # Count instances in each video
    video_info['total_instance'] = video_feature['instance_ref'].nunique()
    
    # Mount index dataframe
    VIDEO_INDEX_DTFRAME = pd.concat([VIDEO_INDEX_DTFRAME, video_info], axis=0, ignore_index=True)

# %% [markdown]
# ## Show the number of each origin video

# %%
print('Total DD-Local Videos:', len(VIDEO_INDEX_DTFRAME.query("origin_vid == 'D'")))
print('Total YT-Online Videos:', len(VIDEO_INDEX_DTFRAME.query("origin_vid == 'Y'")))
# Out:
# Total DD-Local Videos: 28
# Total YT-Online Videos: 42

# %% [markdown]
# ## Show information for all LOCAL VIDEOS

# %%
VIDEO_INDEX_DTFRAME
# Out:
#     video_id origin_vid process_status   link_video  height_vid  width_vid  \
# 0          1          D              L  295xopXuU5E         720       1280
# 1          2          D              L  2q_eNp4mDGU         720       1280
# 2          3          D              L  4W09LPCCJ4U         720       1280
# 3          4          D              L  5KY8V6HBAro         720       1280
# 4          5          D              L  61gzN0c9K3g         720       1280
# ..       ...        ...            ...          ...         ...        ...
# 65        38          Y              L  fL1WMdft3OE         720        406
# 66        39          Y              L  zAvkbjxA7UY        1280        720
# 67        40          Y              L  Azp4Wd8Vb8E        1280        720
# 68        41          Y              L  2ftkADtZKAc        1280        720
# 69        42          Y              L  o-IMRj3ajPY        1280        720
#
#     duration_vid   fps_vid  total_frames  time_step_fr  total_instance
# 0          89.30  29.97003          2676      0.033367               3
# 1          83.68  29.97003          2507      0.033367               3
# 2          79.90  29.97003          2394      0.033367               3
# 3         213.28  30.00000          6398      0.033333               1
# 4         142.78  29.97003          4279      0.033367               3
# ..           ...       ...           ...           ...             ...
# 65        207.66  30.00000          6229      0.033333               1
# 66         46.25  30.00000          1387      0.033333               2
# 67         56.63  29.97003          1697      0.033367               1
# 68         47.95  30.00000          1438      0.033333               2
# 69         54.20  29.97003          1624      0.033367               3
#
# [70 rows x 11 columns]

# %% [markdown]
# ## Show information for all Youtube VIDEOS

# %%
VIDEO_INDEX_DTFRAME.query("origin_vid == 'Y'")
# Out:
#     video_id origin_vid process_status   link_video  height_vid  width_vid  \
# 28         1          Y              L  gwIcgyqioPo         720       1280
# 29         2          Y              L  CwjV6MDU9E8         720       1280
# 30         3          Y              L  oa1QJL7tv4g         720       1280
# 31         4          Y              L  mE45MLeTUOw         720       1280
# 32         5          Y              L  _uiqV7p3fwM         720       1280
# 33         6          Y              L  wexzvClUcUk         720       1280
# 34         7          Y              L  tt4TF1wqz9U         720       1280
# 35         8          Y              L  DSaj9qMwvLI         720       1280
# 36         9          Y              L  yKCUTZaKgNA         720       1280
# 37        10          Y              L  OUAWJRALAzQ         720       1280
# 38        11          Y              L  LOS5WB75gkY         720       1280
# 39        12          Y              L  05SLQsbY310         720        406
# 40        13          Y              L  e6ME0UGNwNQ         720       1280
# 41        14          Y              L  aRs0k5pPXQo         720       1280
# 42        15          Y              L  9cg3wsfoU40         360        200
# 43        16          Y              L  qNrJbE0U5fg         360        360
# 44        17          Y              L  nxFUViPHEnc         720       1056
# 45        18          Y              L  Y5q2CaJxVXg         720       1280
# 46        19          Y              L  591eurlufSo         360        640
# 47        20          Y              L  LeXArY1x9zo         720        406
# 48        21          Y              L  ec_OJbZ4ByQ         720        406
# 49        22          Y              L  hqHWFrG1my8         720        406
# 50        23          Y              L  R-oBT97ujqQ         720        406
# 51        24          Y              L  1kEXoDqDMMA         720        406
# 52        25          Y              L  2vwi5y5UKgk         720       1280
# 53        26          Y              L  B3LilEisx_s         720        720
# 54        27          Y              L  gbegsiuprlA         720       1280
# 55        28          Y              L  ojbMAVRG_o4         720       1280
# 56        29          Y              L  X9WfTOwx05g         720       1280
# 57        30          Y              L  utwNhk3nmVU         360        640
# 58        31          Y              L  LrjlW00kkws         720       1280
# 59        32          Y              L  HgVBxs5G1zE         360        640
# 60        33          Y              L  pzCuKh7QyOA         720       1280
# 61        34          Y              L  J8JCvKDqkj8         720       1280
# 62        35          Y              L  H7GYeKu9L_8         360        202
# 63        36          Y              L  w69hIDMXSaw        1280        720
# 64        37          Y              L  2HkUPY2eo4E         720       1280
# 65        38          Y              L  fL1WMdft3OE         720        406
# 66        39          Y              L  zAvkbjxA7UY        1280        720
# 67        40          Y              L  Azp4Wd8Vb8E        1280        720
# 68        41          Y              L  2ftkADtZKAc        1280        720
# 69        42          Y              L  o-IMRj3ajPY        1280        720
#
#     duration_vid    fps_vid  total_frames  time_step_fr  total_instance
# 28         54.45  23.976024          1305      0.041708               2
# 29        226.60  23.976024          5432      0.041708               1
# 30        109.57  30.000000          3287      0.033333               1
# 31         59.00  30.000000          1770      0.033333               2
# 32         82.08  23.976024          1967      0.041708               2
# 33        352.85  25.000000          8821      0.040000               2
# 34        249.80  29.970030          7486      0.033367               1
# 35        451.40  29.970030         13528      0.033367               2
# 36         43.35  29.970030          1299      0.033367               2
# 37        121.74  30.000000          3652      0.033333               1
# 38        204.38  23.976024          4900      0.041708               1
# 39         39.71  29.970030          1190      0.033367               1
# 40         81.01  29.970030          2428      0.033367               1
# 41         61.60  29.970030          1846      0.033367               1
# 42        102.68  30.000000          3080      0.033333               1
# 43        103.93  29.700000          3086      0.033670               1
# 44         99.40  30.000000          2982      0.033333               2
# 45         80.25  30.000000          2407      0.033333               6
# 46         91.18  30.000000          2735      0.033333               1
# 47        183.04  30.000000          5491      0.033333               1
# 48        133.98  29.970030          4015      0.033367               1
# 49         40.87  30.000000          1226      0.033333               1
# 50         50.50  30.000000          1515      0.033333               1
# 51         30.77  30.000000           923      0.033333               1
# 52         93.72  30.000000          2811      0.033333               3
# 53         54.98  30.000000          1649      0.033333               1
# 54         45.98  23.690000          1089      0.042212               1
# 55         63.88  29.870000          1908      0.033478               1
# 56        129.99  30.000000          3899      0.033333               1
# 57        137.69  21.050000          2898      0.047506               1
# 58        207.45  29.970030          6217      0.033367               2
# 59         63.69  29.000000          1847      0.034483               1
# 60        105.72  29.920000          3163      0.033422               2
# 61         46.60  30.000000          1398      0.033333               1
# 62         79.44  29.970030          2380      0.033367               1
# 63        115.22  30.000000          3456      0.033333               1
# 64        168.81  25.000000          4220      0.040000               1
# 65        207.66  30.000000          6229      0.033333               1
# 66         46.25  30.000000          1387      0.033333               2
# 67         56.63  29.970030          1697      0.033367               1
# 68         47.95  30.000000          1438      0.033333               2
# 69         54.20  29.970030          1624      0.033367               3

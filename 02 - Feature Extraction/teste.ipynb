# %%
import yt_dlp

def get_video_info(video_url):
    ydl_opts = {
        'quiet': True  # Silencia a saída detalhada do yt-dlp para deixar o resultado mais limpo
    }
    
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        try:
            # Extrai informações do vídeo
            info_dict = ydl.extract_info(video_url, download=False)
            
            # Exibe algumas informações básicas
            print("Título:", info_dict.get('title'))
            print("Autor:", info_dict.get('uploader'))
            print("Visualizações:", info_dict.get('view_count'))
            print("Duração (segundos):", info_dict.get('duration'))
            print("Avaliação média:", info_dict.get('average_rating'))
            print("URL de download:", info_dict.get('url'))
        
        except yt_dlp.utils.DownloadError as e:
            print("Erro ao obter informações:", str(e))

# URL de exemplo para testar
video_url = 'https://www.youtube.com/watch?v=dQw4w9WgXcQ'
get_video_info(video_url)
# Out:
# Título: Rick Astley - Never Gonna Give You Up (Official Music Video)
# Autor: Rick Astley
# Visualizações: 1589508940
# Duração (segundos): 212
# Avaliação média: None
# URL de download: None

# %%
import yt_dlp
import cv2
import os

def download_video(video_url, output_path='video.mp4'):
    ydl_opts = {
        'outtmpl': output_path,  # Define o caminho e o nome do arquivo de saída
        'format': 'bestvideo+bestaudio/best',  # Baixa o melhor formato de vídeo e áudio disponível
        'quiet': False
    }
    
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        ydl.download([video_url]) # MODIFICAR AQ
        print("ydl", ydl)
    print(f"Vídeo baixado com sucesso em: {output_path}")

def extract_frames(video_path, output_folder='frames'):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    cap = cv2.VideoCapture(video_path)
    frame_count = 0
    
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        
        # Salva o frame como uma imagem
        frame_filename = os.path.join(output_folder, f'frame_{frame_count:04d}.jpg')
        cv2.imwrite(frame_filename, frame)
        frame_count += 1
    
    cap.release()
    print(f"{frame_count} frames extraídos e salvos em '{output_folder}'.")

# URL do vídeo do YouTube
video_url = 'https://www.youtube.com/watch?v=dQw4w9WgXcQ'

# Passos para baixar o vídeo e extrair frames
download_video(video_url, 'downloaded_video.mp4')
extract_frames('downloaded_video.mp4')
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=dQw4w9WgXcQ
# [youtube] dQw4w9WgXcQ: Downloading webpage
# [youtube] dQw4w9WgXcQ: Downloading ios player API JSON
# [youtube] dQw4w9WgXcQ: Downloading mweb player API JSON
# [youtube] dQw4w9WgXcQ: Downloading m3u8 information
# [info] dQw4w9WgXcQ: Downloading 1 format(s): 616+251
# [download] downloaded_video.mp4.webm has already been downloaded
# ydl <yt_dlp.YoutubeDL.YoutubeDL object at 0x000002608E345660>
# Vídeo baixado com sucesso em: downloaded_video.mp4
# 0 frames extraídos e salvos em 'frames'.

# %%
import cv2
import yt_dlp

def process_video_stream(video_url):
    # Configurações do yt_dlp para obter os detalhes do vídeo
    ydl_opts = {
        'quiet': True,
        'format': 'bestvideo+bestaudio/best',
        'noplaylist': True,
    }
    
    # Obtendo informações detalhadas sobre o vídeo
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        info = ydl.extract_info(video_url, download=False)
        
        # Procurando a melhor URL de vídeo no campo "formats"
        video_stream_url = None
        for fmt in info['formats']:
            if fmt.get('vcodec') != 'none':  # Ignora streams apenas de áudio
                video_stream_url = fmt['url']
                print("video_stream_url", video_stream_url)
                break
        
        if not video_stream_url:
            print("Nenhum stream de vídeo encontrado.")
            return
    
    # Abrindo o stream com OpenCV
    cap = cv2.VideoCapture(video_stream_url)
    if not cap.isOpened():
        print("Erro ao abrir o stream de vídeo.")
        return

    frame_count = 0

    while True:
        ret, frame = cap.read()
        if not ret:
            break  # Acabaram os frames
        
        frame_count += 1

        # Exemplo de extração de features com OpenCV (ORB)
        orb = cv2.ORB_create()
        keypoints, descriptors = orb.detectAndCompute(frame, None)

        print(f"Frame {frame_count}: {len(keypoints)} keypoints detectados.")

        # Exibir o frame (opcional, para debug)
        # cv2.imshow('Frame', frame)
        # if cv2.waitKey(1) & 0xFF == ord('q'):
        #     break

    cap.release()
    cv2.destroyAllWindows()
    print(f"Processamento concluído. Total de frames: {frame_count}")

# URL do vídeo para teste
video_url = 'https://www.youtube.com/watch?v=dQw4w9WgXcQ'
video_url = 'https://www.youtube.com/watch?v=gwIcgyqioPo'
process_video_stream(video_url)
# Out:
# video_stream_url https://manifest.googlevideo.com/api/manifest/hls_playlist/expire/1731093362/ei/Eg8uZ_WCHZnw1sQPo_KkkQk/ip/187.49.116.18/id/83021c832aa2a0fa/itag/269/source/youtube/requiressl/yes/ratebypass/yes/pfa/1/sgovp/clen%3D281057%3Bdur%3D54.471%3Bgir%3Dyes%3Bitag%3D160%3Blmt%3D1724681816114201/rqh/1/hls_chunk_host/rr1---sn-pmcg-4vgl.googlevideo.com/xpc/EgVo2aDSNQ%3D%3D/met/1731071762,/mh/h1/mm/31,26/mn/sn-pmcg-4vgl,sn-gpv7yn7l/ms/au,onr/mv/m/mvi/1/pl/24/rms/au,au/initcwndbps/980000/vprv/1/playlist_type/DVR/dover/13/txp/5309224/mt/1731071356/fvip/2/short_key/1/keepalive/yes/fexp/51312688,51326932/sparams/expire,ei,ip,id,itag,source,requiressl,ratebypass,pfa,sgovp,rqh,xpc,vprv,playlist_type/sig/AJfQdSswRgIhAOMKFJPLZC8MXXCmnO5Td9RUfmHPzftZvAq45mhLJoD2AiEA8Bv7mXeo3mxo0gKgTRW9cdgAVMlEeqngQAHmL411lCE%3D/lsparams/hls_chunk_host,met,mh,mm,mn,ms,mv,mvi,pl,rms,initcwndbps/lsig/ACJ0pHgwRQIge_lI7_efWeJ1x-N1FJbGlHX7Dp-4ccNvpmgS8xffwggCIQC_5UxgdrmvhmFV5wzfd32tkLOR10LZJsoIY6ms8LZrgQ%3D%3D/playlist/index.m3u8
# Frame 1: 0 keypoints detectados.
# Frame 2: 0 keypoints detectados.
# Frame 3: 0 keypoints detectados.
# Frame 4: 0 keypoints detectados.
# Frame 5: 0 keypoints detectados.
# Frame 6: 0 keypoints detectados.
# Frame 7: 0 keypoints detectados.
# Frame 8: 0 keypoints detectados.
# Frame 9: 0 keypoints detectados.
# Frame 10: 0 keypoints detectados.
# Frame 11: 0 keypoints detectados.
# Frame 12: 0 keypoints detectados.
# Frame 13: 1 keypoints detectados.
# Frame 14: 4 keypoints detectados.
# Frame 15: 17 keypoints detectados.
# Frame 16: 21 keypoints detectados.
# Frame 17: 29 keypoints detectados.
# Frame 18: 41 keypoints detectados.
# Frame 19: 51 keypoints detectados.
# Frame 20: 92 keypoints detectados.
# Frame 21: 92 keypoints detectados.
# Frame 22: 95 keypoints detectados.
# Frame 23: 100 keypoints detectados.
# Frame 24: 103 keypoints detectados.
# Frame 25: 109 keypoints detectados.
# Frame 26: 118 keypoints detectados.
# Frame 27: 122 keypoints detectados.
# Frame 28: 135 keypoints detectados.
# Frame 29: 133 keypoints detectados.
# Frame 30: 141 keypoints detectados.
# Frame 31: 142 keypoints detectados.
# Frame 32: 138 keypoints detectados.
# Frame 33: 135 keypoints detectados.
# Frame 34: 132 keypoints detectados.
# Frame 35: 139 keypoints detectados.
# Frame 36: 152 keypoints detectados.
# Frame 37: 145 keypoints detectados.
# Frame 38: 138 keypoints detectados.
# Frame 39: 139 keypoints detectados.
# Frame 40: 132 keypoints detectados.
# Frame 41: 139 keypoints detectados.
# Frame 42: 143 keypoints detectados.
# Frame 43: 140 keypoints detectados.
# Frame 44: 148 keypoints detectados.
# Frame 45: 133 keypoints detectados.
# Frame 46: 153 keypoints detectados.
# Frame 47: 155 keypoints detectados.
# Frame 48: 143 keypoints detectados.
# Frame 49: 152 keypoints detectados.
# Frame 50: 139 keypoints detectados.
# Frame 51: 147 keypoints detectados.
# Frame 52: 147 keypoints detectados.
# Frame 53: 149 keypoints detectados.
# Frame 54: 150 keypoints detectados.
# Frame 55: 145 keypoints detectados.
# Frame 56: 145 keypoints detectados.
# Frame 57: 135 keypoints detectados.
# Frame 58: 138 keypoints detectados.
# Frame 59: 142 keypoints detectados.
# Frame 60: 142 keypoints detectados.
# Frame 61: 143 keypoints detectados.
# Frame 62: 141 keypoints detectados.
# Frame 63: 134 keypoints detectados.
# Frame 64: 139 keypoints detectados.
# Frame 65: 131 keypoints detectados.
# Frame 66: 131 keypoints detectados.
# Frame 67: 135 keypoints detectados.
# Frame 68: 128 keypoints detectados.
# Frame 69: 145 keypoints detectados.
# Frame 70: 135 keypoints detectados.
# Frame 71: 132 keypoints detectados.
# Frame 72: 127 keypoints detectados.
# Frame 73: 126 keypoints detectados.
# Frame 74: 147 keypoints detectados.
# Frame 75: 141 keypoints detectados.
# Frame 76: 137 keypoints detectados.
# Frame 77: 131 keypoints detectados.
# Frame 78: 137 keypoints detectados.
# Frame 79: 137 keypoints detectados.
# Frame 80: 135 keypoints detectados.
# Frame 81: 131 keypoints detectados.
# Frame 82: 136 keypoints detectados.
# Frame 83: 143 keypoints detectados.
# Frame 84: 134 keypoints detectados.
# Frame 85: 138 keypoints detectados.
# Frame 86: 144 keypoints detectados.
# Frame 87: 146 keypoints detectados.
# Frame 88: 142 keypoints detectados.
# Frame 89: 138 keypoints detectados.
# Frame 90: 139 keypoints detectados.
# Frame 91: 135 keypoints detectados.
# Frame 92: 131 keypoints detectados.
# Frame 93: 130 keypoints detectados.
# Frame 94: 133 keypoints detectados.
# Frame 95: 133 keypoints detectados.
# Frame 96: 138 keypoints detectados.
# Frame 97: 142 keypoints detectados.
# Frame 98: 136 keypoints detectados.
# Frame 99: 130 keypoints detectados.
# Frame 100: 136 keypoints detectados.
# Frame 101: 133 keypoints detectados.
# Frame 102: 133 keypoints detectados.
# Frame 103: 137 keypoints detectados.
# Frame 104: 136 keypoints detectados.
# Frame 105: 137 keypoints detectados.
# Frame 106: 134 keypoints detectados.
# Frame 107: 138 keypoints detectados.
# Frame 108: 152 keypoints detectados.
# Frame 109: 158 keypoints detectados.
# Frame 110: 154 keypoints detectados.
# Frame 111: 141 keypoints detectados.
# Frame 112: 150 keypoints detectados.
# Frame 113: 151 keypoints detectados.
# Frame 114: 143 keypoints detectados.
# Frame 115: 144 keypoints detectados.
# Frame 116: 141 keypoints detectados.
# Frame 117: 149 keypoints detectados.
# Frame 118: 141 keypoints detectados.
# Frame 119: 149 keypoints detectados.
# Frame 120: 147 keypoints detectados.
# Frame 121: 157 keypoints detectados.
# Frame 122: 139 keypoints detectados.
# Frame 123: 148 keypoints detectados.
# Frame 124: 138 keypoints detectados.
# Frame 125: 145 keypoints detectados.
# Frame 126: 151 keypoints detectados.
# Frame 127: 156 keypoints detectados.
# Frame 128: 153 keypoints detectados.
# Frame 129: 153 keypoints detectados.
# Frame 130: 144 keypoints detectados.
# Frame 131: 143 keypoints detectados.
# Frame 132: 146 keypoints detectados.
# Frame 133: 137 keypoints detectados.
# Frame 134: 140 keypoints detectados.
# Frame 135: 127 keypoints detectados.
# Frame 136: 143 keypoints detectados.
# Frame 137: 145 keypoints detectados.
# Frame 138: 138 keypoints detectados.
# Frame 139: 152 keypoints detectados.
# Frame 140: 160 keypoints detectados.
# Frame 141: 156 keypoints detectados.
# Frame 142: 150 keypoints detectados.
# Frame 143: 150 keypoints detectados.
# Frame 144: 154 keypoints detectados.
# Frame 145: 139 keypoints detectados.
# Frame 146: 142 keypoints detectados.
# Frame 147: 150 keypoints detectados.
# Frame 148: 148 keypoints detectados.
# Frame 149: 138 keypoints detectados.
# Frame 150: 143 keypoints detectados.
# Frame 151: 137 keypoints detectados.
# Frame 152: 144 keypoints detectados.
# Frame 153: 147 keypoints detectados.
# Frame 154: 145 keypoints detectados.
# Frame 155: 147 keypoints detectados.
# Frame 156: 142 keypoints detectados.
# Frame 157: 149 keypoints detectados.
# Frame 158: 154 keypoints detectados.
# Frame 159: 154 keypoints detectados.
# Frame 160: 144 keypoints detectados.
# Frame 161: 140 keypoints detectados.
# Frame 162: 150 keypoints detectados.
# Frame 163: 148 keypoints detectados.
# Frame 164: 149 keypoints detectados.
# Frame 165: 143 keypoints detectados.
# Frame 166: 144 keypoints detectados.
# Frame 167: 144 keypoints detectados.
# Frame 168: 144 keypoints detectados.
# Frame 169: 130 keypoints detectados.
# Frame 170: 133 keypoints detectados.
# Frame 171: 114 keypoints detectados.
# Frame 172: 128 keypoints detectados.
# Frame 173: 131 keypoints detectados.
# Frame 174: 144 keypoints detectados.
# Frame 175: 152 keypoints detectados.
# Frame 176: 143 keypoints detectados.
# Frame 177: 153 keypoints detectados.
# Frame 178: 152 keypoints detectados.
# Frame 179: 145 keypoints detectados.
# Frame 180: 149 keypoints detectados.
# Frame 181: 142 keypoints detectados.
# Frame 182: 138 keypoints detectados.
# Frame 183: 147 keypoints detectados.
# Frame 184: 132 keypoints detectados.
# Frame 185: 127 keypoints detectados.
# Frame 186: 130 keypoints detectados.
# Frame 187: 127 keypoints detectados.
# Frame 188: 131 keypoints detectados.
# Frame 189: 135 keypoints detectados.
# Frame 190: 140 keypoints detectados.
# Frame 191: 143 keypoints detectados.
# Frame 192: 125 keypoints detectados.
# Frame 193: 127 keypoints detectados.
# Frame 194: 124 keypoints detectados.
# Frame 195: 128 keypoints detectados.
# Frame 196: 132 keypoints detectados.
# Frame 197: 134 keypoints detectados.
# Frame 198: 139 keypoints detectados.
# Frame 199: 141 keypoints detectados.
# Frame 200: 143 keypoints detectados.
# Frame 201: 153 keypoints detectados.
# Frame 202: 155 keypoints detectados.
# Frame 203: 140 keypoints detectados.
# Frame 204: 139 keypoints detectados.
# Frame 205: 138 keypoints detectados.
# Frame 206: 139 keypoints detectados.
# Frame 207: 130 keypoints detectados.
# Frame 208: 130 keypoints detectados.
# Frame 209: 126 keypoints detectados.
# Frame 210: 133 keypoints detectados.
# Frame 211: 133 keypoints detectados.
# Frame 212: 131 keypoints detectados.
# Frame 213: 135 keypoints detectados.
# Frame 214: 145 keypoints detectados.
# Frame 215: 143 keypoints detectados.
# Frame 216: 140 keypoints detectados.
# Frame 217: 144 keypoints detectados.
# Frame 218: 137 keypoints detectados.
# Frame 219: 137 keypoints detectados.
# Frame 220: 135 keypoints detectados.
# Frame 221: 139 keypoints detectados.
# Frame 222: 139 keypoints detectados.
# Frame 223: 131 keypoints detectados.
# Frame 224: 146 keypoints detectados.
# Frame 225: 139 keypoints detectados.
# Frame 226: 150 keypoints detectados.
# Frame 227: 148 keypoints detectados.
# Frame 228: 153 keypoints detectados.
# Frame 229: 147 keypoints detectados.
# Frame 230: 147 keypoints detectados.
# Frame 231: 142 keypoints detectados.
# Frame 232: 143 keypoints detectados.
# Frame 233: 144 keypoints detectados.
# Frame 234: 146 keypoints detectados.
# Frame 235: 143 keypoints detectados.
# Frame 236: 155 keypoints detectados.
# Frame 237: 162 keypoints detectados.
# Frame 238: 168 keypoints detectados.
# Frame 239: 149 keypoints detectados.
# Frame 240: 124 keypoints detectados.
# Frame 241: 134 keypoints detectados.
# Frame 242: 139 keypoints detectados.
# Frame 243: 137 keypoints detectados.
# Frame 244: 133 keypoints detectados.
# Frame 245: 131 keypoints detectados.
# Frame 246: 141 keypoints detectados.
# Frame 247: 134 keypoints detectados.
# Frame 248: 136 keypoints detectados.
# Frame 249: 140 keypoints detectados.
# Frame 250: 129 keypoints detectados.
# Frame 251: 122 keypoints detectados.
# Frame 252: 117 keypoints detectados.
# Frame 253: 106 keypoints detectados.
# Frame 254: 111 keypoints detectados.
# Frame 255: 117 keypoints detectados.
# Frame 256: 126 keypoints detectados.
# Frame 257: 127 keypoints detectados.
# Frame 258: 125 keypoints detectados.
# Frame 259: 129 keypoints detectados.
# Frame 260: 122 keypoints detectados.
# Frame 261: 134 keypoints detectados.
# Frame 262: 133 keypoints detectados.
# Frame 263: 124 keypoints detectados.
# Frame 264: 117 keypoints detectados.
# Frame 265: 132 keypoints detectados.
# Frame 266: 141 keypoints detectados.
# Frame 267: 142 keypoints detectados.
# Frame 268: 142 keypoints detectados.
# Frame 269: 138 keypoints detectados.
# Frame 270: 130 keypoints detectados.
# Frame 271: 137 keypoints detectados.
# Frame 272: 142 keypoints detectados.
# Frame 273: 115 keypoints detectados.
# Frame 274: 112 keypoints detectados.
# Frame 275: 124 keypoints detectados.
# Frame 276: 128 keypoints detectados.
# Frame 277: 132 keypoints detectados.
# Frame 278: 130 keypoints detectados.
# Frame 279: 127 keypoints detectados.
# Frame 280: 137 keypoints detectados.
# Frame 281: 141 keypoints detectados.
# Frame 282: 143 keypoints detectados.
# Frame 283: 141 keypoints detectados.
# Frame 284: 126 keypoints detectados.
# Frame 285: 131 keypoints detectados.
# Frame 286: 118 keypoints detectados.
# Frame 287: 130 keypoints detectados.
# Frame 288: 132 keypoints detectados.
# Frame 289: 134 keypoints detectados.
# Frame 290: 129 keypoints detectados.
# Frame 291: 132 keypoints detectados.
# Frame 292: 124 keypoints detectados.
# Frame 293: 133 keypoints detectados.
# Frame 294: 138 keypoints detectados.
# Frame 295: 118 keypoints detectados.
# Frame 296: 120 keypoints detectados.
# Frame 297: 128 keypoints detectados.
# Frame 298: 125 keypoints detectados.
# Frame 299: 132 keypoints detectados.
# Frame 300: 122 keypoints detectados.
# Frame 301: 128 keypoints detectados.
# Frame 302: 115 keypoints detectados.
# Frame 303: 128 keypoints detectados.
# Frame 304: 124 keypoints detectados.
# Frame 305: 124 keypoints detectados.
# Frame 306: 122 keypoints detectados.
# Frame 307: 129 keypoints detectados.
# Frame 308: 128 keypoints detectados.
# Frame 309: 129 keypoints detectados.
# Frame 310: 133 keypoints detectados.
# Frame 311: 134 keypoints detectados.
# Frame 312: 129 keypoints detectados.
# Frame 313: 129 keypoints detectados.
# Frame 314: 130 keypoints detectados.
# Frame 315: 128 keypoints detectados.
# Frame 316: 138 keypoints detectados.
# Frame 317: 133 keypoints detectados.
# Frame 318: 126 keypoints detectados.
# Frame 319: 128 keypoints detectados.
# Frame 320: 130 keypoints detectados.
# Frame 321: 133 keypoints detectados.
# Frame 322: 120 keypoints detectados.
# Frame 323: 122 keypoints detectados.
# Frame 324: 116 keypoints detectados.
# Frame 325: 122 keypoints detectados.
# Frame 326: 129 keypoints detectados.
# Frame 327: 124 keypoints detectados.
# Frame 328: 128 keypoints detectados.
# Frame 329: 121 keypoints detectados.
# Frame 330: 119 keypoints detectados.
# Frame 331: 116 keypoints detectados.
# Frame 332: 120 keypoints detectados.
# Frame 333: 124 keypoints detectados.
# Frame 334: 124 keypoints detectados.
# Frame 335: 116 keypoints detectados.
# Frame 336: 119 keypoints detectados.
# Frame 337: 129 keypoints detectados.
# Frame 338: 116 keypoints detectados.
# Frame 339: 118 keypoints detectados.
# Frame 340: 126 keypoints detectados.
# Frame 341: 124 keypoints detectados.
# Frame 342: 119 keypoints detectados.
# Frame 343: 111 keypoints detectados.
# Frame 344: 109 keypoints detectados.
# Frame 345: 119 keypoints detectados.
# Frame 346: 115 keypoints detectados.
# Frame 347: 120 keypoints detectados.
# Frame 348: 122 keypoints detectados.
# Frame 349: 121 keypoints detectados.
# Frame 350: 124 keypoints detectados.
# Frame 351: 127 keypoints detectados.
# Frame 352: 135 keypoints detectados.
# Frame 353: 132 keypoints detectados.
# Frame 354: 132 keypoints detectados.
# Frame 355: 122 keypoints detectados.
# Frame 356: 116 keypoints detectados.
# Frame 357: 123 keypoints detectados.
# Frame 358: 120 keypoints detectados.
# Frame 359: 104 keypoints detectados.
# Frame 360: 115 keypoints detectados.
# Frame 361: 108 keypoints detectados.
# Frame 362: 116 keypoints detectados.
# Frame 363: 111 keypoints detectados.
# Frame 364: 115 keypoints detectados.
# Frame 365: 115 keypoints detectados.
# Frame 366: 111 keypoints detectados.
# Frame 367: 107 keypoints detectados.
# Frame 368: 107 keypoints detectados.
# Frame 369: 113 keypoints detectados.
# Frame 370: 103 keypoints detectados.
# Frame 371: 111 keypoints detectados.
# Frame 372: 111 keypoints detectados.
# Frame 373: 120 keypoints detectados.
# Frame 374: 109 keypoints detectados.
# Frame 375: 116 keypoints detectados.
# Frame 376: 120 keypoints detectados.
# Frame 377: 128 keypoints detectados.
# Frame 378: 123 keypoints detectados.
# Frame 379: 131 keypoints detectados.
# Frame 380: 117 keypoints detectados.
# Frame 381: 129 keypoints detectados.
# Frame 382: 121 keypoints detectados.
# Frame 383: 120 keypoints detectados.
# Frame 384: 132 keypoints detectados.
# Frame 385: 137 keypoints detectados.
# Frame 386: 131 keypoints detectados.
# Frame 387: 128 keypoints detectados.
# Frame 388: 139 keypoints detectados.
# Frame 389: 139 keypoints detectados.
# Frame 390: 136 keypoints detectados.
# Frame 391: 135 keypoints detectados.
# Frame 392: 126 keypoints detectados.
# Frame 393: 137 keypoints detectados.
# Frame 394: 133 keypoints detectados.
# Frame 395: 137 keypoints detectados.
# Frame 396: 131 keypoints detectados.
# Frame 397: 144 keypoints detectados.
# Frame 398: 143 keypoints detectados.
# Frame 399: 145 keypoints detectados.
# Frame 400: 151 keypoints detectados.
# Frame 401: 146 keypoints detectados.
# Frame 402: 149 keypoints detectados.
# Frame 403: 129 keypoints detectados.
# Frame 404: 130 keypoints detectados.
# Frame 405: 137 keypoints detectados.
# Frame 406: 139 keypoints detectados.
# Frame 407: 138 keypoints detectados.
# Frame 408: 130 keypoints detectados.
# Frame 409: 142 keypoints detectados.
# Frame 410: 137 keypoints detectados.
# Frame 411: 126 keypoints detectados.
# Frame 412: 128 keypoints detectados.
# Frame 413: 134 keypoints detectados.
# Frame 414: 134 keypoints detectados.
# Frame 415: 141 keypoints detectados.
# Frame 416: 141 keypoints detectados.
# Frame 417: 145 keypoints detectados.
# Frame 418: 136 keypoints detectados.
# Frame 419: 129 keypoints detectados.
# Frame 420: 114 keypoints detectados.
# Frame 421: 139 keypoints detectados.
# Frame 422: 128 keypoints detectados.
# Frame 423: 130 keypoints detectados.
# Frame 424: 137 keypoints detectados.
# Frame 425: 144 keypoints detectados.
# Frame 426: 129 keypoints detectados.
# Frame 427: 124 keypoints detectados.
# Frame 428: 118 keypoints detectados.
# Frame 429: 119 keypoints detectados.
# Frame 430: 114 keypoints detectados.
# Frame 431: 124 keypoints detectados.
# Frame 432: 144 keypoints detectados.
# Frame 433: 144 keypoints detectados.
# Frame 434: 138 keypoints detectados.
# Frame 435: 140 keypoints detectados.
# Frame 436: 130 keypoints detectados.
# Frame 437: 125 keypoints detectados.
# Frame 438: 118 keypoints detectados.
# Frame 439: 125 keypoints detectados.
# Frame 440: 138 keypoints detectados.
# Frame 441: 142 keypoints detectados.
# Frame 442: 141 keypoints detectados.
# Frame 443: 122 keypoints detectados.
# Frame 444: 124 keypoints detectados.
# Frame 445: 131 keypoints detectados.
# Frame 446: 135 keypoints detectados.
# Frame 447: 148 keypoints detectados.
# Frame 448: 151 keypoints detectados.
# Frame 449: 145 keypoints detectados.
# Frame 450: 151 keypoints detectados.
# Frame 451: 146 keypoints detectados.
# Frame 452: 128 keypoints detectados.
# Frame 453: 131 keypoints detectados.
# Frame 454: 131 keypoints detectados.
# Frame 455: 126 keypoints detectados.
# Frame 456: 128 keypoints detectados.
# Frame 457: 136 keypoints detectados.
# Frame 458: 128 keypoints detectados.
# Frame 459: 127 keypoints detectados.
# Frame 460: 134 keypoints detectados.
# Frame 461: 127 keypoints detectados.
# Frame 462: 133 keypoints detectados.
# Frame 463: 116 keypoints detectados.
# Frame 464: 125 keypoints detectados.
# Frame 465: 128 keypoints detectados.
# Frame 466: 125 keypoints detectados.
# Frame 467: 124 keypoints detectados.
# Frame 468: 119 keypoints detectados.
# Frame 469: 124 keypoints detectados.
# Frame 470: 125 keypoints detectados.
# Frame 471: 117 keypoints detectados.
# Frame 472: 121 keypoints detectados.
# Frame 473: 123 keypoints detectados.
# Frame 474: 118 keypoints detectados.
# Frame 475: 119 keypoints detectados.
# Frame 476: 120 keypoints detectados.
# Frame 477: 121 keypoints detectados.
# Frame 478: 129 keypoints detectados.
# Frame 479: 123 keypoints detectados.
# Frame 480: 140 keypoints detectados.
# Frame 481: 135 keypoints detectados.
# Frame 482: 140 keypoints detectados.
# Frame 483: 141 keypoints detectados.
# Frame 484: 148 keypoints detectados.
# Frame 485: 138 keypoints detectados.
# Frame 486: 138 keypoints detectados.
# Frame 487: 129 keypoints detectados.
# Frame 488: 131 keypoints detectados.
# Frame 489: 141 keypoints detectados.
# Frame 490: 136 keypoints detectados.
# Frame 491: 137 keypoints detectados.
# Frame 492: 139 keypoints detectados.
# Frame 493: 139 keypoints detectados.
# Frame 494: 133 keypoints detectados.
# Frame 495: 146 keypoints detectados.
# Frame 496: 134 keypoints detectados.
# Frame 497: 136 keypoints detectados.
# Frame 498: 136 keypoints detectados.
# Frame 499: 140 keypoints detectados.
# Frame 500: 137 keypoints detectados.
# Frame 501: 138 keypoints detectados.
# Frame 502: 138 keypoints detectados.
# Frame 503: 132 keypoints detectados.
# Frame 504: 129 keypoints detectados.
# Frame 505: 129 keypoints detectados.
# Frame 506: 135 keypoints detectados.
# Frame 507: 129 keypoints detectados.
# Frame 508: 128 keypoints detectados.
# Frame 509: 136 keypoints detectados.
# Frame 510: 130 keypoints detectados.
# Frame 511: 128 keypoints detectados.
# Frame 512: 135 keypoints detectados.
# Frame 513: 131 keypoints detectados.
# Frame 514: 139 keypoints detectados.
# Frame 515: 141 keypoints detectados.
# Frame 516: 138 keypoints detectados.
# Frame 517: 142 keypoints detectados.
# Frame 518: 138 keypoints detectados.
# Frame 519: 157 keypoints detectados.
# Frame 520: 144 keypoints detectados.
# Frame 521: 147 keypoints detectados.
# Frame 522: 148 keypoints detectados.
# Frame 523: 128 keypoints detectados.
# Frame 524: 133 keypoints detectados.
# Frame 525: 129 keypoints detectados.
# Frame 526: 129 keypoints detectados.
# Frame 527: 140 keypoints detectados.
# Frame 528: 145 keypoints detectados.
# Frame 529: 142 keypoints detectados.
# Frame 530: 143 keypoints detectados.
# Frame 531: 142 keypoints detectados.
# Frame 532: 152 keypoints detectados.
# Frame 533: 137 keypoints detectados.
# Frame 534: 140 keypoints detectados.
# Frame 535: 146 keypoints detectados.
# Frame 536: 139 keypoints detectados.
# Frame 537: 125 keypoints detectados.
# Frame 538: 143 keypoints detectados.
# Frame 539: 131 keypoints detectados.
# Frame 540: 131 keypoints detectados.
# Frame 541: 134 keypoints detectados.
# Frame 542: 138 keypoints detectados.
# Frame 543: 127 keypoints detectados.
# Frame 544: 137 keypoints detectados.
# Frame 545: 138 keypoints detectados.
# Frame 546: 134 keypoints detectados.
# Frame 547: 132 keypoints detectados.
# Frame 548: 128 keypoints detectados.
# Frame 549: 132 keypoints detectados.
# Frame 550: 139 keypoints detectados.
# Frame 551: 131 keypoints detectados.
# Frame 552: 142 keypoints detectados.
# Frame 553: 143 keypoints detectados.
# Frame 554: 139 keypoints detectados.
# Frame 555: 139 keypoints detectados.
# Frame 556: 135 keypoints detectados.
# Frame 557: 138 keypoints detectados.
# Frame 558: 130 keypoints detectados.
# Frame 559: 124 keypoints detectados.
# Frame 560: 137 keypoints detectados.
# Frame 561: 134 keypoints detectados.
# Frame 562: 134 keypoints detectados.
# Frame 563: 131 keypoints detectados.
# Frame 564: 135 keypoints detectados.
# Frame 565: 144 keypoints detectados.
# Frame 566: 136 keypoints detectados.
# Frame 567: 138 keypoints detectados.
# Frame 568: 126 keypoints detectados.
# Frame 569: 129 keypoints detectados.
# Frame 570: 122 keypoints detectados.
# Frame 571: 122 keypoints detectados.
# Frame 572: 119 keypoints detectados.
# Frame 573: 123 keypoints detectados.
# Frame 574: 123 keypoints detectados.
# Frame 575: 118 keypoints detectados.
# Frame 576: 121 keypoints detectados.
# Frame 577: 122 keypoints detectados.
# Frame 578: 121 keypoints detectados.
# Frame 579: 127 keypoints detectados.
# Frame 580: 126 keypoints detectados.
# Frame 581: 133 keypoints detectados.
# Frame 582: 131 keypoints detectados.
# Frame 583: 135 keypoints detectados.
# Frame 584: 124 keypoints detectados.
# Frame 585: 130 keypoints detectados.
# Frame 586: 126 keypoints detectados.
# Frame 587: 141 keypoints detectados.
# Frame 588: 133 keypoints detectados.
# Frame 589: 142 keypoints detectados.
# Frame 590: 137 keypoints detectados.
# Frame 591: 134 keypoints detectados.
# Frame 592: 131 keypoints detectados.
# Frame 593: 128 keypoints detectados.
# Frame 594: 140 keypoints detectados.
# Frame 595: 137 keypoints detectados.
# Frame 596: 134 keypoints detectados.
# Frame 597: 135 keypoints detectados.
# Frame 598: 139 keypoints detectados.
# Frame 599: 126 keypoints detectados.
# Frame 600: 130 keypoints detectados.
# Frame 601: 123 keypoints detectados.
# Frame 602: 130 keypoints detectados.
# Frame 603: 129 keypoints detectados.
# Frame 604: 127 keypoints detectados.
# Frame 605: 124 keypoints detectados.
# Frame 606: 121 keypoints detectados.
# Frame 607: 130 keypoints detectados.
# Frame 608: 133 keypoints detectados.
# Frame 609: 146 keypoints detectados.
# Frame 610: 142 keypoints detectados.
# Frame 611: 151 keypoints detectados.
# Frame 612: 145 keypoints detectados.
# Frame 613: 142 keypoints detectados.
# Frame 614: 132 keypoints detectados.
# Frame 615: 134 keypoints detectados.
# Frame 616: 130 keypoints detectados.
# Frame 617: 127 keypoints detectados.
# Frame 618: 136 keypoints detectados.
# Frame 619: 124 keypoints detectados.
# Frame 620: 117 keypoints detectados.
# Frame 621: 119 keypoints detectados.
# Frame 622: 103 keypoints detectados.
# Frame 623: 112 keypoints detectados.
# Frame 624: 127 keypoints detectados.
# Frame 625: 124 keypoints detectados.
# Frame 626: 110 keypoints detectados.
# Frame 627: 117 keypoints detectados.
# Frame 628: 123 keypoints detectados.
# Frame 629: 124 keypoints detectados.
# Frame 630: 130 keypoints detectados.
# Frame 631: 134 keypoints detectados.
# Frame 632: 131 keypoints detectados.
# Frame 633: 139 keypoints detectados.
# Frame 634: 133 keypoints detectados.
# Frame 635: 138 keypoints detectados.
# Frame 636: 146 keypoints detectados.
# Frame 637: 136 keypoints detectados.
# Frame 638: 134 keypoints detectados.
# Frame 639: 129 keypoints detectados.
# Frame 640: 142 keypoints detectados.
# Frame 641: 146 keypoints detectados.
# Frame 642: 138 keypoints detectados.
# Frame 643: 128 keypoints detectados.
# Frame 644: 127 keypoints detectados.
# Frame 645: 135 keypoints detectados.
# Frame 646: 140 keypoints detectados.
# Frame 647: 142 keypoints detectados.
# Frame 648: 134 keypoints detectados.
# Frame 649: 144 keypoints detectados.
# Frame 650: 136 keypoints detectados.
# Frame 651: 141 keypoints detectados.
# Frame 652: 143 keypoints detectados.
# Frame 653: 144 keypoints detectados.
# Frame 654: 142 keypoints detectados.
# Frame 655: 141 keypoints detectados.
# Frame 656: 141 keypoints detectados.
# Frame 657: 144 keypoints detectados.
# Frame 658: 149 keypoints detectados.
# Frame 659: 138 keypoints detectados.
# Frame 660: 145 keypoints detectados.
# Frame 661: 138 keypoints detectados.
# Frame 662: 134 keypoints detectados.
# Frame 663: 131 keypoints detectados.
# Frame 664: 111 keypoints detectados.
# Frame 665: 130 keypoints detectados.
# Frame 666: 131 keypoints detectados.
# Frame 667: 127 keypoints detectados.
# Frame 668: 129 keypoints detectados.
# Frame 669: 137 keypoints detectados.
# Frame 670: 115 keypoints detectados.
# Frame 671: 125 keypoints detectados.
# Frame 672: 117 keypoints detectados.
# Frame 673: 122 keypoints detectados.
# Frame 674: 118 keypoints detectados.
# Frame 675: 131 keypoints detectados.
# Frame 676: 130 keypoints detectados.
# Frame 677: 138 keypoints detectados.
# Frame 678: 132 keypoints detectados.
# Frame 679: 133 keypoints detectados.
# Frame 680: 127 keypoints detectados.
# Frame 681: 126 keypoints detectados.
# Frame 682: 128 keypoints detectados.
# Frame 683: 136 keypoints detectados.
# Frame 684: 142 keypoints detectados.
# Frame 685: 147 keypoints detectados.
# Frame 686: 145 keypoints detectados.
# Frame 687: 143 keypoints detectados.
# Frame 688: 129 keypoints detectados.
# Frame 689: 140 keypoints detectados.
# Frame 690: 138 keypoints detectados.
# Frame 691: 143 keypoints detectados.
# Frame 692: 149 keypoints detectados.
# Frame 693: 143 keypoints detectados.
# Frame 694: 140 keypoints detectados.
# Frame 695: 134 keypoints detectados.
# Frame 696: 128 keypoints detectados.
# Frame 697: 130 keypoints detectados.
# Frame 698: 143 keypoints detectados.
# Frame 699: 149 keypoints detectados.
# Frame 700: 140 keypoints detectados.
# Frame 701: 134 keypoints detectados.
# Frame 702: 125 keypoints detectados.
# Frame 703: 136 keypoints detectados.
# Frame 704: 120 keypoints detectados.
# Frame 705: 132 keypoints detectados.
# Frame 706: 129 keypoints detectados.
# Frame 707: 130 keypoints detectados.
# Frame 708: 119 keypoints detectados.
# Frame 709: 122 keypoints detectados.
# Frame 710: 130 keypoints detectados.
# Frame 711: 132 keypoints detectados.
# Frame 712: 136 keypoints detectados.
# Frame 713: 130 keypoints detectados.
# Frame 714: 128 keypoints detectados.
# Frame 715: 138 keypoints detectados.
# Frame 716: 130 keypoints detectados.
# Frame 717: 130 keypoints detectados.
# Frame 718: 138 keypoints detectados.
# Frame 719: 140 keypoints detectados.
# Frame 720: 138 keypoints detectados.
# Frame 721: 135 keypoints detectados.
# Frame 722: 137 keypoints detectados.
# Frame 723: 144 keypoints detectados.
# Frame 724: 131 keypoints detectados.
# Frame 725: 118 keypoints detectados.
# Frame 726: 124 keypoints detectados.
# Frame 727: 133 keypoints detectados.
# Frame 728: 130 keypoints detectados.
# Frame 729: 132 keypoints detectados.
# Frame 730: 125 keypoints detectados.
# Frame 731: 126 keypoints detectados.
# Frame 732: 132 keypoints detectados.
# Frame 733: 130 keypoints detectados.
# Frame 734: 131 keypoints detectados.
# Frame 735: 151 keypoints detectados.
# Frame 736: 144 keypoints detectados.
# Frame 737: 150 keypoints detectados.
# Frame 738: 148 keypoints detectados.
# Frame 739: 145 keypoints detectados.
# Frame 740: 147 keypoints detectados.
# Frame 741: 145 keypoints detectados.
# Frame 742: 158 keypoints detectados.
# Frame 743: 155 keypoints detectados.
# Frame 744: 144 keypoints detectados.
# Frame 745: 136 keypoints detectados.
# Frame 746: 129 keypoints detectados.
# Frame 747: 132 keypoints detectados.
# Frame 748: 133 keypoints detectados.
# Frame 749: 129 keypoints detectados.
# Frame 750: 140 keypoints detectados.
# Frame 751: 128 keypoints detectados.
# Frame 752: 128 keypoints detectados.
# Frame 753: 125 keypoints detectados.
# Frame 754: 142 keypoints detectados.
# Frame 755: 135 keypoints detectados.
# Frame 756: 139 keypoints detectados.
# Frame 757: 123 keypoints detectados.
# Frame 758: 118 keypoints detectados.
# Frame 759: 125 keypoints detectados.
# Frame 760: 122 keypoints detectados.
# Frame 761: 117 keypoints detectados.
# Frame 762: 124 keypoints detectados.
# Frame 763: 131 keypoints detectados.
# Frame 764: 122 keypoints detectados.
# Frame 765: 134 keypoints detectados.
# Frame 766: 130 keypoints detectados.
# Frame 767: 124 keypoints detectados.
# Frame 768: 115 keypoints detectados.
# Frame 769: 133 keypoints detectados.
# Frame 770: 123 keypoints detectados.
# Frame 771: 132 keypoints detectados.
# Frame 772: 124 keypoints detectados.
# Frame 773: 114 keypoints detectados.
# Frame 774: 113 keypoints detectados.
# Frame 775: 128 keypoints detectados.
# Frame 776: 122 keypoints detectados.
# Frame 777: 127 keypoints detectados.
# Frame 778: 126 keypoints detectados.
# Frame 779: 127 keypoints detectados.
# Frame 780: 119 keypoints detectados.
# Frame 781: 123 keypoints detectados.
# Frame 782: 119 keypoints detectados.
# Frame 783: 118 keypoints detectados.
# Frame 784: 117 keypoints detectados.
# Frame 785: 117 keypoints detectados.
# Frame 786: 116 keypoints detectados.
# Frame 787: 116 keypoints detectados.
# Frame 788: 115 keypoints detectados.
# Frame 789: 106 keypoints detectados.
# Frame 790: 112 keypoints detectados.
# Frame 791: 121 keypoints detectados.
# Frame 792: 129 keypoints detectados.
# Frame 793: 132 keypoints detectados.
# Frame 794: 126 keypoints detectados.
# Frame 795: 133 keypoints detectados.
# Frame 796: 131 keypoints detectados.
# Frame 797: 120 keypoints detectados.
# Frame 798: 136 keypoints detectados.
# Frame 799: 139 keypoints detectados.
# Frame 800: 132 keypoints detectados.
# Frame 801: 115 keypoints detectados.
# Frame 802: 129 keypoints detectados.
# Frame 803: 138 keypoints detectados.
# Frame 804: 132 keypoints detectados.
# Frame 805: 130 keypoints detectados.
# Frame 806: 127 keypoints detectados.
# Frame 807: 131 keypoints detectados.
# Frame 808: 128 keypoints detectados.
# Frame 809: 134 keypoints detectados.
# Frame 810: 132 keypoints detectados.
# Frame 811: 139 keypoints detectados.
# Frame 812: 129 keypoints detectados.
# Frame 813: 132 keypoints detectados.
# Frame 814: 131 keypoints detectados.
# Frame 815: 138 keypoints detectados.
# Frame 816: 130 keypoints detectados.
# Frame 817: 121 keypoints detectados.
# Frame 818: 121 keypoints detectados.
# Frame 819: 128 keypoints detectados.
# Frame 820: 120 keypoints detectados.
# Frame 821: 116 keypoints detectados.
# Frame 822: 122 keypoints detectados.
# Frame 823: 125 keypoints detectados.
# Frame 824: 135 keypoints detectados.
# Frame 825: 129 keypoints detectados.
# Frame 826: 121 keypoints detectados.
# Frame 827: 118 keypoints detectados.
# Frame 828: 123 keypoints detectados.
# Frame 829: 118 keypoints detectados.
# Frame 830: 126 keypoints detectados.
# Frame 831: 123 keypoints detectados.
# Frame 832: 123 keypoints detectados.
# Frame 833: 135 keypoints detectados.
# Frame 834: 119 keypoints detectados.
# Frame 835: 116 keypoints detectados.
# Frame 836: 117 keypoints detectados.
# Frame 837: 118 keypoints detectados.
# Frame 838: 115 keypoints detectados.
# Frame 839: 115 keypoints detectados.
# Frame 840: 116 keypoints detectados.
# Frame 841: 114 keypoints detectados.
# Frame 842: 105 keypoints detectados.
# Frame 843: 117 keypoints detectados.
# Frame 844: 119 keypoints detectados.
# Frame 845: 118 keypoints detectados.
# Frame 846: 118 keypoints detectados.
# Frame 847: 118 keypoints detectados.
# Frame 848: 120 keypoints detectados.
# Frame 849: 124 keypoints detectados.
# Frame 850: 117 keypoints detectados.
# Frame 851: 120 keypoints detectados.
# Frame 852: 114 keypoints detectados.
# Frame 853: 127 keypoints detectados.
# Frame 854: 126 keypoints detectados.
# Frame 855: 116 keypoints detectados.
# Frame 856: 127 keypoints detectados.
# Frame 857: 129 keypoints detectados.
# Frame 858: 117 keypoints detectados.
# Frame 859: 111 keypoints detectados.
# Frame 860: 130 keypoints detectados.
# Frame 861: 126 keypoints detectados.
# Frame 862: 131 keypoints detectados.
# Frame 863: 114 keypoints detectados.
# Frame 864: 119 keypoints detectados.
# Frame 865: 125 keypoints detectados.
# Frame 866: 114 keypoints detectados.
# Frame 867: 120 keypoints detectados.
# Frame 868: 123 keypoints detectados.
# Frame 869: 122 keypoints detectados.
# Frame 870: 122 keypoints detectados.
# Frame 871: 125 keypoints detectados.
# Frame 872: 123 keypoints detectados.
# Frame 873: 135 keypoints detectados.
# Frame 874: 126 keypoints detectados.
# Frame 875: 123 keypoints detectados.
# Frame 876: 127 keypoints detectados.
# Frame 877: 134 keypoints detectados.
# Frame 878: 131 keypoints detectados.
# Frame 879: 125 keypoints detectados.
# Frame 880: 128 keypoints detectados.
# Frame 881: 131 keypoints detectados.
# Frame 882: 119 keypoints detectados.
# Frame 883: 117 keypoints detectados.
# Frame 884: 118 keypoints detectados.
# Frame 885: 130 keypoints detectados.
# Frame 886: 132 keypoints detectados.
# Frame 887: 134 keypoints detectados.
# Frame 888: 135 keypoints detectados.
# Frame 889: 134 keypoints detectados.
# Frame 890: 130 keypoints detectados.
# Frame 891: 140 keypoints detectados.
# Frame 892: 142 keypoints detectados.
# Frame 893: 143 keypoints detectados.
# Frame 894: 138 keypoints detectados.
# Frame 895: 135 keypoints detectados.
# Frame 896: 128 keypoints detectados.
# Frame 897: 123 keypoints detectados.
# Frame 898: 115 keypoints detectados.
# Frame 899: 125 keypoints detectados.
# Frame 900: 116 keypoints detectados.
# Frame 901: 128 keypoints detectados.
# Frame 902: 118 keypoints detectados.
# Frame 903: 118 keypoints detectados.
# Frame 904: 126 keypoints detectados.
# Frame 905: 134 keypoints detectados.
# Frame 906: 132 keypoints detectados.
# Frame 907: 139 keypoints detectados.
# Frame 908: 147 keypoints detectados.
# Frame 909: 141 keypoints detectados.
# Frame 910: 137 keypoints detectados.
# Frame 911: 125 keypoints detectados.
# Frame 912: 126 keypoints detectados.
# Frame 913: 128 keypoints detectados.
# Frame 914: 123 keypoints detectados.
# Frame 915: 127 keypoints detectados.
# Frame 916: 131 keypoints detectados.
# Frame 917: 121 keypoints detectados.
# Frame 918: 121 keypoints detectados.
# Frame 919: 131 keypoints detectados.
# Frame 920: 133 keypoints detectados.
# Frame 921: 133 keypoints detectados.
# Frame 922: 136 keypoints detectados.
# Frame 923: 132 keypoints detectados.
# Frame 924: 150 keypoints detectados.
# Frame 925: 139 keypoints detectados.
# Frame 926: 137 keypoints detectados.
# Frame 927: 141 keypoints detectados.
# Frame 928: 138 keypoints detectados.
# Frame 929: 140 keypoints detectados.
# Frame 930: 131 keypoints detectados.
# Frame 931: 118 keypoints detectados.
# Frame 932: 138 keypoints detectados.
# Frame 933: 130 keypoints detectados.
# Frame 934: 127 keypoints detectados.
# Frame 935: 125 keypoints detectados.
# Frame 936: 119 keypoints detectados.
# Frame 937: 128 keypoints detectados.
# Frame 938: 131 keypoints detectados.
# Frame 939: 127 keypoints detectados.
# Frame 940: 131 keypoints detectados.
# Frame 941: 125 keypoints detectados.
# Frame 942: 128 keypoints detectados.
# Frame 943: 135 keypoints detectados.
# Frame 944: 124 keypoints detectados.
# Frame 945: 134 keypoints detectados.
# Frame 946: 126 keypoints detectados.
# Frame 947: 131 keypoints detectados.
# Frame 948: 139 keypoints detectados.
# Frame 949: 137 keypoints detectados.
# Frame 950: 138 keypoints detectados.
# Frame 951: 136 keypoints detectados.
# Frame 952: 142 keypoints detectados.
# Frame 953: 143 keypoints detectados.
# Frame 954: 140 keypoints detectados.
# Frame 955: 139 keypoints detectados.
# Frame 956: 144 keypoints detectados.
# Frame 957: 140 keypoints detectados.
# Frame 958: 134 keypoints detectados.
# Frame 959: 137 keypoints detectados.
# Frame 960: 139 keypoints detectados.
# Frame 961: 137 keypoints detectados.
# Frame 962: 134 keypoints detectados.
# Frame 963: 126 keypoints detectados.
# Frame 964: 139 keypoints detectados.
# Frame 965: 135 keypoints detectados.
# Frame 966: 139 keypoints detectados.
# Frame 967: 127 keypoints detectados.
# Frame 968: 124 keypoints detectados.
# Frame 969: 144 keypoints detectados.
# Frame 970: 134 keypoints detectados.
# Frame 971: 137 keypoints detectados.
# Frame 972: 139 keypoints detectados.
# Frame 973: 137 keypoints detectados.
# Frame 974: 138 keypoints detectados.
# Frame 975: 125 keypoints detectados.
# Frame 976: 138 keypoints detectados.
# Frame 977: 130 keypoints detectados.
# Frame 978: 144 keypoints detectados.
# Frame 979: 142 keypoints detectados.
# Frame 980: 150 keypoints detectados.
# Frame 981: 148 keypoints detectados.
# Frame 982: 135 keypoints detectados.
# Frame 983: 138 keypoints detectados.
# Frame 984: 139 keypoints detectados.
# Frame 985: 134 keypoints detectados.
# Frame 986: 139 keypoints detectados.
# Frame 987: 131 keypoints detectados.
# Frame 988: 131 keypoints detectados.
# Frame 989: 134 keypoints detectados.
# Frame 990: 131 keypoints detectados.
# Frame 991: 126 keypoints detectados.
# Frame 992: 134 keypoints detectados.
# Frame 993: 136 keypoints detectados.
# Frame 994: 141 keypoints detectados.
# Frame 995: 129 keypoints detectados.
# Frame 996: 127 keypoints detectados.
# Frame 997: 137 keypoints detectados.
# Frame 998: 136 keypoints detectados.
# Frame 999: 138 keypoints detectados.
# Frame 1000: 136 keypoints detectados.
# Frame 1001: 129 keypoints detectados.
# Frame 1002: 143 keypoints detectados.
# Frame 1003: 138 keypoints detectados.
# Frame 1004: 122 keypoints detectados.
# Frame 1005: 127 keypoints detectados.
# Frame 1006: 133 keypoints detectados.
# Frame 1007: 142 keypoints detectados.
# Frame 1008: 136 keypoints detectados.
# Frame 1009: 137 keypoints detectados.
# Frame 1010: 134 keypoints detectados.
# Frame 1011: 129 keypoints detectados.
# Frame 1012: 126 keypoints detectados.
# Frame 1013: 135 keypoints detectados.
# Frame 1014: 134 keypoints detectados.
# Frame 1015: 125 keypoints detectados.
# Frame 1016: 134 keypoints detectados.
# Frame 1017: 127 keypoints detectados.
# Frame 1018: 128 keypoints detectados.
# Frame 1019: 129 keypoints detectados.
# Frame 1020: 135 keypoints detectados.
# Frame 1021: 130 keypoints detectados.
# Frame 1022: 127 keypoints detectados.
# Frame 1023: 125 keypoints detectados.
# Frame 1024: 128 keypoints detectados.
# Frame 1025: 126 keypoints detectados.
# Frame 1026: 125 keypoints detectados.
# Frame 1027: 126 keypoints detectados.
# Frame 1028: 137 keypoints detectados.
# Frame 1029: 134 keypoints detectados.
# Frame 1030: 134 keypoints detectados.
# Frame 1031: 136 keypoints detectados.
# Frame 1032: 130 keypoints detectados.
# Frame 1033: 133 keypoints detectados.
# Frame 1034: 130 keypoints detectados.
# Frame 1035: 126 keypoints detectados.
# Frame 1036: 123 keypoints detectados.
# Frame 1037: 119 keypoints detectados.
# Frame 1038: 110 keypoints detectados.
# Frame 1039: 113 keypoints detectados.
# Frame 1040: 109 keypoints detectados.
# Frame 1041: 102 keypoints detectados.
# Frame 1042: 85 keypoints detectados.
# Frame 1043: 79 keypoints detectados.
# Frame 1044: 76 keypoints detectados.
# Frame 1045: 80 keypoints detectados.
# Frame 1046: 74 keypoints detectados.
# Frame 1047: 61 keypoints detectados.
# Frame 1048: 60 keypoints detectados.
# Frame 1049: 56 keypoints detectados.
# Frame 1050: 51 keypoints detectados.
# Frame 1051: 48 keypoints detectados.
# Frame 1052: 44 keypoints detectados.
# Frame 1053: 38 keypoints detectados.
# Frame 1054: 25 keypoints detectados.
# Frame 1055: 27 keypoints detectados.
# Frame 1056: 26 keypoints detectados.
# Frame 1057: 18 keypoints detectados.
# Frame 1058: 16 keypoints detectados.
# Frame 1059: 17 keypoints detectados.
# Frame 1060: 17 keypoints detectados.
# Frame 1061: 13 keypoints detectados.
# Frame 1062: 10 keypoints detectados.
# Frame 1063: 12 keypoints detectados.
# Frame 1064: 7 keypoints detectados.
# Frame 1065: 8 keypoints detectados.
# Frame 1066: 8 keypoints detectados.
# Frame 1067: 6 keypoints detectados.
# Frame 1068: 10 keypoints detectados.
# Frame 1069: 9 keypoints detectados.
# Frame 1070: 0 keypoints detectados.
# Frame 1071: 0 keypoints detectados.
# Frame 1072: 0 keypoints detectados.
# Frame 1073: 0 keypoints detectados.
# Frame 1074: 0 keypoints detectados.
# Frame 1075: 0 keypoints detectados.
# Frame 1076: 0 keypoints detectados.
# Frame 1077: 0 keypoints detectados.
# Frame 1078: 0 keypoints detectados.
# Frame 1079: 0 keypoints detectados.
# Frame 1080: 0 keypoints detectados.
# Frame 1081: 0 keypoints detectados.
# Frame 1082: 0 keypoints detectados.
# Frame 1083: 0 keypoints detectados.
# Frame 1084: 0 keypoints detectados.
# Frame 1085: 0 keypoints detectados.
# Frame 1086: 0 keypoints detectados.
# Frame 1087: 0 keypoints detectados.
# Frame 1088: 0 keypoints detectados.
# Frame 1089: 0 keypoints detectados.
# Frame 1090: 0 keypoints detectados.
# Frame 1091: 0 keypoints detectados.
# Frame 1092: 0 keypoints detectados.
# Frame 1093: 0 keypoints detectados.
# Frame 1094: 0 keypoints detectados.
# Frame 1095: 0 keypoints detectados.
# Frame 1096: 0 keypoints detectados.
# Frame 1097: 0 keypoints detectados.
# Frame 1098: 0 keypoints detectados.
# Frame 1099: 0 keypoints detectados.
# Frame 1100: 0 keypoints detectados.
# Frame 1101: 0 keypoints detectados.
# Frame 1102: 0 keypoints detectados.
# Frame 1103: 0 keypoints detectados.
# Frame 1104: 0 keypoints detectados.
# Frame 1105: 9 keypoints detectados.
# Frame 1106: 7 keypoints detectados.
# Frame 1107: 22 keypoints detectados.
# Frame 1108: 27 keypoints detectados.
# Frame 1109: 49 keypoints detectados.
# Frame 1110: 59 keypoints detectados.
# Frame 1111: 85 keypoints detectados.
# Frame 1112: 109 keypoints detectados.
# Frame 1113: 120 keypoints detectados.
# Frame 1114: 152 keypoints detectados.
# Frame 1115: 174 keypoints detectados.
# Frame 1116: 194 keypoints detectados.
# Frame 1117: 215 keypoints detectados.
# Frame 1118: 229 keypoints detectados.
# Frame 1119: 231 keypoints detectados.
# Frame 1120: 259 keypoints detectados.
# Frame 1121: 284 keypoints detectados.
# Frame 1122: 293 keypoints detectados.
# Frame 1123: 305 keypoints detectados.
# Frame 1124: 322 keypoints detectados.
# Frame 1125: 310 keypoints detectados.
# Frame 1126: 328 keypoints detectados.
# Frame 1127: 328 keypoints detectados.
# Frame 1128: 332 keypoints detectados.
# Frame 1129: 344 keypoints detectados.
# Frame 1130: 346 keypoints detectados.
# Frame 1131: 348 keypoints detectados.
# Frame 1132: 346 keypoints detectados.
# Frame 1133: 349 keypoints detectados.
# Frame 1134: 344 keypoints detectados.
# Frame 1135: 348 keypoints detectados.
# Frame 1136: 347 keypoints detectados.
# Frame 1137: 343 keypoints detectados.
# Frame 1138: 343 keypoints detectados.
# Frame 1139: 345 keypoints detectados.
# Frame 1140: 347 keypoints detectados.
# Frame 1141: 347 keypoints detectados.
# Frame 1142: 346 keypoints detectados.
# Frame 1143: 344 keypoints detectados.
# Frame 1144: 348 keypoints detectados.
# Frame 1145: 348 keypoints detectados.
# Frame 1146: 344 keypoints detectados.
# Frame 1147: 344 keypoints detectados.
# Frame 1148: 347 keypoints detectados.
# Frame 1149: 346 keypoints detectados.
# Frame 1150: 346 keypoints detectados.
# Frame 1151: 346 keypoints detectados.
# Frame 1152: 346 keypoints detectados.
# Frame 1153: 346 keypoints detectados.
# Frame 1154: 346 keypoints detectados.
# Frame 1155: 346 keypoints detectados.
# Frame 1156: 346 keypoints detectados.
# Frame 1157: 346 keypoints detectados.
# Frame 1158: 346 keypoints detectados.
# Frame 1159: 346 keypoints detectados.
# Frame 1160: 346 keypoints detectados.
# Frame 1161: 346 keypoints detectados.
# Frame 1162: 346 keypoints detectados.
# Frame 1163: 346 keypoints detectados.
# Frame 1164: 346 keypoints detectados.
# Frame 1165: 346 keypoints detectados.
# Frame 1166: 346 keypoints detectados.
# Frame 1167: 346 keypoints detectados.
# Frame 1168: 346 keypoints detectados.
# Frame 1169: 346 keypoints detectados.
# Frame 1170: 346 keypoints detectados.
# Frame 1171: 346 keypoints detectados.
# Frame 1172: 346 keypoints detectados.
# Frame 1173: 346 keypoints detectados.
# Frame 1174: 346 keypoints detectados.
# Frame 1175: 346 keypoints detectados.
# Frame 1176: 346 keypoints detectados.
# Frame 1177: 346 keypoints detectados.
# Frame 1178: 346 keypoints detectados.
# Frame 1179: 346 keypoints detectados.
# Frame 1180: 346 keypoints detectados.
# Frame 1181: 346 keypoints detectados.
# Frame 1182: 346 keypoints detectados.
# Frame 1183: 346 keypoints detectados.
# Frame 1184: 346 keypoints detectados.
# Frame 1185: 346 keypoints detectados.
# Frame 1186: 346 keypoints detectados.
# Frame 1187: 346 keypoints detectados.
# Frame 1188: 346 keypoints detectados.
# Frame 1189: 346 keypoints detectados.
# Frame 1190: 346 keypoints detectados.
# Frame 1191: 346 keypoints detectados.
# Frame 1192: 346 keypoints detectados.
# Frame 1193: 346 keypoints detectados.
# Frame 1194: 346 keypoints detectados.
# Frame 1195: 346 keypoints detectados.
# Frame 1196: 346 keypoints detectados.
# Frame 1197: 346 keypoints detectados.
# Frame 1198: 346 keypoints detectados.
# Frame 1199: 346 keypoints detectados.
# Frame 1200: 346 keypoints detectados.
# Frame 1201: 346 keypoints detectados.
# Frame 1202: 346 keypoints detectados.
# Frame 1203: 346 keypoints detectados.
# Frame 1204: 346 keypoints detectados.
# Frame 1205: 346 keypoints detectados.
# Frame 1206: 346 keypoints detectados.
# Frame 1207: 346 keypoints detectados.
# Frame 1208: 346 keypoints detectados.
# Frame 1209: 346 keypoints detectados.
# Frame 1210: 346 keypoints detectados.
# Frame 1211: 346 keypoints detectados.
# Frame 1212: 346 keypoints detectados.
# Frame 1213: 346 keypoints detectados.
# Frame 1214: 346 keypoints detectados.
# Frame 1215: 346 keypoints detectados.
# Frame 1216: 346 keypoints detectados.
# Frame 1217: 346 keypoints detectados.
# Frame 1218: 346 keypoints detectados.
# Frame 1219: 346 keypoints detectados.
# Frame 1220: 346 keypoints detectados.
# Frame 1221: 346 keypoints detectados.
# Frame 1222: 346 keypoints detectados.
# Frame 1223: 346 keypoints detectados.
# Frame 1224: 346 keypoints detectados.
# Frame 1225: 346 keypoints detectados.
# Frame 1226: 346 keypoints detectados.
# Frame 1227: 346 keypoints detectados.
# Frame 1228: 346 keypoints detectados.
# Frame 1229: 346 keypoints detectados.
# Frame 1230: 346 keypoints detectados.
# Frame 1231: 346 keypoints detectados.
# Frame 1232: 346 keypoints detectados.
# Frame 1233: 346 keypoints detectados.
# Frame 1234: 346 keypoints detectados.
# Frame 1235: 346 keypoints detectados.
# Frame 1236: 346 keypoints detectados.
# Frame 1237: 346 keypoints detectados.
# Frame 1238: 346 keypoints detectados.
# Frame 1239: 346 keypoints detectados.
# Frame 1240: 346 keypoints detectados.
# Frame 1241: 346 keypoints detectados.
# Frame 1242: 346 keypoints detectados.
# Frame 1243: 346 keypoints detectados.
# Frame 1244: 346 keypoints detectados.
# Frame 1245: 346 keypoints detectados.
# Frame 1246: 346 keypoints detectados.
# Frame 1247: 346 keypoints detectados.
# Frame 1248: 346 keypoints detectados.
# Frame 1249: 346 keypoints detectados.
# Frame 1250: 346 keypoints detectados.
# Frame 1251: 346 keypoints detectados.
# Frame 1252: 346 keypoints detectados.
# Frame 1253: 346 keypoints detectados.
# Frame 1254: 346 keypoints detectados.
# Frame 1255: 346 keypoints detectados.
# Frame 1256: 346 keypoints detectados.
# Frame 1257: 346 keypoints detectados.
# Frame 1258: 346 keypoints detectados.
# Frame 1259: 346 keypoints detectados.
# Frame 1260: 346 keypoints detectados.
# Frame 1261: 346 keypoints detectados.
# Frame 1262: 346 keypoints detectados.
# Frame 1263: 346 keypoints detectados.
# Frame 1264: 346 keypoints detectados.
# Frame 1265: 346 keypoints detectados.
# Frame 1266: 346 keypoints detectados.
# Frame 1267: 346 keypoints detectados.
# Frame 1268: 346 keypoints detectados.
# Frame 1269: 346 keypoints detectados.
# Frame 1270: 346 keypoints detectados.
# Frame 1271: 346 keypoints detectados.
# Frame 1272: 346 keypoints detectados.
# Frame 1273: 346 keypoints detectados.
# Frame 1274: 346 keypoints detectados.
# Frame 1275: 346 keypoints detectados.
# Frame 1276: 346 keypoints detectados.
# Frame 1277: 346 keypoints detectados.
# Frame 1278: 346 keypoints detectados.
# Frame 1279: 346 keypoints detectados.
# Frame 1280: 346 keypoints detectados.
# Frame 1281: 346 keypoints detectados.
# Frame 1282: 346 keypoints detectados.
# Frame 1283: 346 keypoints detectados.
# Frame 1284: 346 keypoints detectados.
# Frame 1285: 346 keypoints detectados.
# Frame 1286: 346 keypoints detectados.
# Frame 1287: 346 keypoints detectados.
# Frame 1288: 346 keypoints detectados.
# Frame 1289: 346 keypoints detectados.
# Frame 1290: 346 keypoints detectados.
# Frame 1291: 346 keypoints detectados.
# Frame 1292: 346 keypoints detectados.
# Frame 1293: 346 keypoints detectados.
# Frame 1294: 346 keypoints detectados.
# Frame 1295: 346 keypoints detectados.
# Frame 1296: 346 keypoints detectados.
# Frame 1297: 345 keypoints detectados.
# Frame 1298: 345 keypoints detectados.
# Frame 1299: 345 keypoints detectados.
# Frame 1300: 0 keypoints detectados.
# Frame 1301: 0 keypoints detectados.
# Frame 1302: 0 keypoints detectados.
# Frame 1303: 0 keypoints detectados.
# Frame 1304: 0 keypoints detectados.
# Frame 1305: 0 keypoints detectados.
# Frame 1306: 0 keypoints detectados.
# Processamento concluído. Total de frames: 1306

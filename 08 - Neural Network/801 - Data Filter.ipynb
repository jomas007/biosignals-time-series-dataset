# %%
import os
import sys
import pandas as pd
from tslearn.metrics import dtw

from sklearn.preprocessing import StandardScaler

# Import library with current code functions
sys.path.append(os.path.join("..", "lib"))
import general_functions as gf, files_paths as fp

# %%
def preprocess_data_current_dataset(dataset_path):
    SEQUENCES_NAME_FILE = dataset_path
    SEQUENCES = pd.read_csv(SEQUENCES_NAME_FILE)
    SEQUENCES.drop(columns=['Unnamed: 0'], inplace=True)
    
    SEQUENCES_DT = SEQUENCES.copy()

    # Select features
    features = SEQUENCES_DT.columns.to_list()[3:25]
    
    sample_id = set(SEQUENCES_DT['sample_id'])
    
    grouped_data = []
    for sample_id, group in SEQUENCES_DT.groupby('sample_id'):

        frame_seq = SEQUENCES_DT[SEQUENCES_DT.sample_id == sample_id].iloc[:].frame_seq
        sample_id = SEQUENCES_DT[SEQUENCES_DT.sample_id == sample_id].iloc[0].sample_id
        video_id = SEQUENCES_DT[SEQUENCES_DT.sample_id == sample_id].iloc[0].video_id
        sequence_features = group[features]
        label_measures = SEQUENCES_DT[SEQUENCES_DT.sample_id == sample_id].iloc[0].label_measures
        label = SEQUENCES_DT[SEQUENCES_DT.sample_id == sample_id].iloc[0].label
        seed_name = SEQUENCES_DT[SEQUENCES_DT.sample_id == sample_id].iloc[0].seed_name

        frame_start = SEQUENCES_DT[SEQUENCES_DT.sample_id == sample_id].iloc[0].frame_seq
        frame_end = SEQUENCES_DT[SEQUENCES_DT.sample_id == sample_id].iloc[-1].frame_seq


        grouped_data.append((frame_seq, sample_id, video_id, sequence_features, label_measures, label, seed_name, frame_start, frame_end))
    
    return grouped_data

# %%
def find_item_with_number(file_list, number):
    number_str = str(number).zfill(10)
    for file_path in file_list:
        if number_str in file_path:
            return file_path
    return None

# %%
def distant_dtw_filter(current_occurrence):
    new_data = current_occurrence

    valid = 1
    dtw_measures = []
    
    sample_id = new_data[1]
    emotion = new_data[5]
    seed_number = new_data[6]
    video_id = new_data[2]
    frame_seq_start = new_data[7]
    frame_seq_end = new_data[8]

    seed_path = find_item_with_number(FILE_LIST_SEED, seed_number)
    df_seed = pd.read_csv(seed_path)
    
    df_seed_features = df_seed.iloc[:, 3:27]
    df_measure_features = new_data[3]

    filtered_df = df_seed_features[df_seed_features['label_measures'] != '{}']

    scaler = StandardScaler()

    for i, (col, acc_distance) in enumerate(columns):
        y_seed = filtered_df[col].values.reshape(-1, 1)
        y_measure = df_measure_features[col].values.reshape(-1, 1)

        y_seed_scaled = scaler.fit_transform(y_seed)
        y_measure_scaled = scaler.fit_transform(y_measure)

        y_seed_scaled = y_seed_scaled.flatten()
        y_measure_scaled = y_measure_scaled.flatten()

        distance = dtw(y_seed_scaled, y_measure_scaled)
        
        dtw_measures.append([col, distance, acc_distance])

        if distance > columns[i][1]:  
            valid = 0
    
    print(f"Sample ID: {sample_id}")
    for col, real_measure, expected_limit in dtw_measures:
        print(f"Col: {col}, DTW distance: {real_measure}, expected limit: {expected_limit}")

    if valid:
        print(f"Seed {seed_number} marking {video_id} as {emotion} from {frame_seq_start} to {frame_seq_end} has been MAINTAINED!\n")
        return new_data
    else:
        print(f"Seed {seed_number} marking {video_id} as {emotion} from {frame_seq_start} to {frame_seq_end} has been REMOVED!\n")
        return -1

# %%
def build_new_filtered_sequence_dataset(new_grouped_data, columns, output_folder='result_sequences'):
    
    parts = current_sequence_file.split('_')
    number = parts[3].split('.')[0]

    output_filename=f'filtered_sequences_{number}'
    for i, item in enumerate(columns):
        output_filename += str(f'_{columns[i][0]}_{columns[i][1]}')
    output_filename += ".CSV"

    # Define the output directory and ensure it exists
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    all_data = []
    
    # Iterate over each item in the new_grouped_data list
    for item in new_grouped_data:
        # Extract each element from the tuple
        frame_seq = item[0].tolist()  # Convert to list
        sample_id = item[1]
        video_id = item[2]
        sequence_features_df = item[3]
        label_measures = item[4]
        label = item[5]
        seed_name = item[6]
        
        # Repeat the single value fields for all rows in sequence_features_df
        num_rows = sequence_features_df.shape[0]
        
        # Create a dictionary for the DataFrame
        data_dict = {
            'frame_seq': frame_seq,
            'sample_id': [sample_id] * num_rows,
            'video_id': [video_id] * num_rows,
            'label_measures': [label_measures] * num_rows,
            'label': [label] * num_rows,
            'seed_name': [seed_name] * num_rows
        }
        
        # Create a DataFrame from the dictionary
        data_df = pd.DataFrame(data_dict)
        
        # Split the DataFrame into two parts and insert sequence_features_df between them
        part1 = data_df[['frame_seq', 'sample_id', 'video_id']]
        part2 = data_df[['label_measures', 'label', 'seed_name']]
        
        # Combine the parts and sequence_features_df
        combined_df = pd.concat([part1.reset_index(drop=True), sequence_features_df.reset_index(drop=True), part2.reset_index(drop=True)], axis=1)
        
        # Append the combined DataFrame to the list
        all_data.append(combined_df)
    
    # Concatenate all DataFrames
    final_df = pd.concat(all_data, ignore_index=True)
    
    # Define the full path for the output file
    output_path = os.path.join(output_folder, output_filename)
    
    # Save the DataFrame to a CSV file
    final_df.to_csv(output_path, index=False)
    
    print(f'Dataset saved to {output_path}')

# %%
sequences_folder = os.path.join("result_sequences")
datase_seed_ck = os.path.join("..", "Dataset", "REF-Gold-Label")
FILE_LIST_VD_DATA_SEQUENCES = gf.find_files_in_all_subdirectories([sequences_folder], "*.CSV")
FILE_LIST_SEED = gf.find_files_in_all_subdirectories([datase_seed_ck], fp.VD_LABELED_L0)

# %%
FILE_LIST_VD_DATA_SEQUENCES
# Out:
# ['result_sequences/DATASET_SEQUENCES_17.CSV',
#  'result_sequences/DATASET_SEQUENCES_2.CSV',
#  'result_sequences/DATASET_SEQUENCES_4.CSV',
#  'result_sequences/filtered_sequences_17_m1_30_m3_25_m12_15_e2_20.CSV']

# %%
current_sequence_file = FILE_LIST_VD_DATA_SEQUENCES[0]
grouped_data = preprocess_data_current_dataset(current_sequence_file)

# %%
smile_data = [emotion for emotion in grouped_data if emotion[5] == 'happy']
print(len(smile_data))
# Out:
# 333

# %%
number_occurrence = 0

# Measure, accepted distance
columns = [
    ['m1', 30], 
    ['m3', 25], 
    ['m12', 15], 
    ['e2', 20]
]

# %%
new_grouped_data = []
for occurrence in grouped_data:
    distance = distant_dtw_filter(occurrence)
    if distance != -1:
        new_grouped_data.append(distance)
# Out:
# Sample ID: 0
# Col: m1, DTW distance: 2.4548661728400694, expected limit: 30
# Col: m3, DTW distance: 2.784821185982177, expected limit: 25
# Col: m12, DTW distance: 1.8138284798272157, expected limit: 15
# Col: e2, DTW distance: 2.2729101113391987, expected limit: 20
# Seed 29 marking 1 as happy from 1011 to 1022 has been MAINTAINED!
#
# Sample ID: 1
# Col: m1, DTW distance: 1.5853839074941134, expected limit: 30
# Col: m3, DTW distance: 3.539424157730818, expected limit: 25
# Col: m12, DTW distance: 2.175161807314891, expected limit: 15
# Col: e2, DTW distance: 2.4204512212194413, expected limit: 20
# Seed 44 marking 1 as happy from 1069 to 1083 has been MAINTAINED!
#
# Sample ID: 2
# Col: m1, DTW distance: 1.527119992518361, expected limit: 30
# Col: m3, DTW distance: 2.0936773052813624, expected limit: 25
# Col: m12, DTW distance: 0.8243762135595738, expected limit: 15
# Col: e2, DTW distance: 1.6665526298168125, expected limit: 20
# Seed 29 marking 1 as happy from 1129 to 1140 has been MAINTAINED!
#
# Sample ID: 3
# Col: m1, DTW distance: 3.0471828595542503, expected limit: 30
# Col: m3, DTW distance: 3.8039753413058732, expected limit: 25
# Col: m12, DTW distance: 2.4149214799536645, expected limit: 15
# Col: e2, DTW distance: 1.2055484549446918, expected limit: 20
# Seed 29 marking 1 as happy from 1314 to 1325 has been MAINTAINED!
#
# Sample ID: 4
# Col: m1, DTW distance: 4.035933026914246, expected limit: 30
# Col: m3, DTW distance: 2.1877873405943924, expected limit: 25
# Col: m12, DTW distance: 3.3141590882435827, expected limit: 15
# Col: e2, DTW distance: 3.0957743625107397, expected limit: 20
# Seed 44 marking 1 as happy from 1584 to 1598 has been MAINTAINED!
#
# Sample ID: 5
# Col: m1, DTW distance: 5.250567472947266, expected limit: 30
# Col: m3, DTW distance: 3.739988967589365, expected limit: 25
# Col: m12, DTW distance: 5.341082272857487, expected limit: 15
# Col: e2, DTW distance: 3.907206774318896, expected limit: 20
# Seed 20 marking 2 as happy from 555 to 594 has been MAINTAINED!
#
# Sample ID: 6
# Col: m1, DTW distance: 4.121086736608744, expected limit: 30
# Col: m3, DTW distance: 4.29686659328562, expected limit: 25
# Col: m12, DTW distance: 1.6885076095500782, expected limit: 15
# Col: e2, DTW distance: 2.513909298972061, expected limit: 20
# Seed 31 marking 2 as happy from 828 to 847 has been MAINTAINED!
#
# Sample ID: 7
# Col: m1, DTW distance: 4.04329485738355, expected limit: 30
# Col: m3, DTW distance: 2.0604629930284064, expected limit: 25
# Col: m12, DTW distance: 1.4348581357551424, expected limit: 15
# Col: e2, DTW distance: 2.3727828984801778, expected limit: 20
# Seed 34 marking 2 as happy from 963 to 976 has been MAINTAINED!
#
# Sample ID: 8
# Col: m1, DTW distance: 4.449014070676644, expected limit: 30
# Col: m3, DTW distance: 3.3348543368428474, expected limit: 25
# Col: m12, DTW distance: 1.7293692905022484, expected limit: 15
# Col: e2, DTW distance: 1.3403367682624137, expected limit: 20
# Seed 22 marking 2 as happy from 1260 to 1288 has been MAINTAINED!
#
# Sample ID: 9
# Col: m1, DTW distance: 2.623499325619363, expected limit: 30
# Col: m3, DTW distance: 1.4041261445476658, expected limit: 25
# Col: m12, DTW distance: 1.2056167901354418, expected limit: 15
# Col: e2, DTW distance: 2.6686426839591895, expected limit: 20
# Seed 45 marking 2 as happy from 1398 to 1409 has been MAINTAINED!
#
# Sample ID: 10
# Col: m1, DTW distance: 3.6606777692230272, expected limit: 30
# Col: m3, DTW distance: 1.5354019981521785, expected limit: 25
# Col: m12, DTW distance: 2.3977673316461265, expected limit: 15
# Col: e2, DTW distance: 2.4477620825263906, expected limit: 20
# Seed 27 marking 2 as happy from 1428 to 1443 has been MAINTAINED!
#
# Sample ID: 11
# Col: m1, DTW distance: 4.832047740054202, expected limit: 30
# Col: m3, DTW distance: 1.7527770914627663, expected limit: 25
# Col: m12, DTW distance: 5.473464920350586, expected limit: 15
# Col: e2, DTW distance: 3.3625260995540094, expected limit: 20
# Seed 38 marking 2 as happy from 1826 to 1852 has been MAINTAINED!
#
# Sample ID: 12
# Col: m1, DTW distance: 2.052975185587674, expected limit: 30
# Col: m3, DTW distance: 3.5881506696858736, expected limit: 25
# Col: m12, DTW distance: 4.13902204621175, expected limit: 15
# Col: e2, DTW distance: 2.004007222487324, expected limit: 20
# Seed 34 marking 3 as happy from 413 to 426 has been MAINTAINED!
#
# Sample ID: 13
# Col: m1, DTW distance: 6.842588746405176, expected limit: 30
# Col: m3, DTW distance: 1.9202704084537223, expected limit: 25
# Col: m12, DTW distance: 3.4774706630451013, expected limit: 15
# Col: e2, DTW distance: 2.083741502616392, expected limit: 20
# Seed 43 marking 3 as happy from 932 to 947 has been MAINTAINED!
#
# Sample ID: 14
# Col: m1, DTW distance: 3.3388636463259846, expected limit: 30
# Col: m3, DTW distance: 2.1201947533719334, expected limit: 25
# Col: m12, DTW distance: 1.5933756139074402, expected limit: 15
# Col: e2, DTW distance: 3.2462560633248345, expected limit: 20
# Seed 16 marking 3 as happy from 1194 to 1214 has been MAINTAINED!
#
# Sample ID: 15
# Col: m1, DTW distance: 6.412620521541762, expected limit: 30
# Col: m3, DTW distance: 2.1842739640915636, expected limit: 25
# Col: m12, DTW distance: 2.6976049385863203, expected limit: 15
# Col: e2, DTW distance: 2.345967439566656, expected limit: 20
# Seed 43 marking 3 as happy from 1439 to 1455 has been MAINTAINED!
#
# Sample ID: 16
# Col: m1, DTW distance: 2.226618010085039, expected limit: 30
# Col: m3, DTW distance: 1.3173848982301244, expected limit: 25
# Col: m12, DTW distance: 1.9897767121942163, expected limit: 15
# Col: e2, DTW distance: 3.9940316773356175, expected limit: 20
# Seed 29 marking 3 as happy from 1515 to 1526 has been MAINTAINED!
#
# Sample ID: 17
# Col: m1, DTW distance: 5.1824110047289755, expected limit: 30
# Col: m3, DTW distance: 2.2175844523397004, expected limit: 25
# Col: m12, DTW distance: 1.838107884376997, expected limit: 15
# Col: e2, DTW distance: 1.8879657040384819, expected limit: 20
# Seed 43 marking 4 as happy from 294 to 309 has been MAINTAINED!
#
# Sample ID: 18
# Col: m1, DTW distance: 3.5480417163192604, expected limit: 30
# Col: m3, DTW distance: 2.0586779080879904, expected limit: 25
# Col: m12, DTW distance: 1.1456175145405183, expected limit: 15
# Col: e2, DTW distance: 2.0881971398027477, expected limit: 20
# Seed 27 marking 4 as happy from 473 to 488 has been MAINTAINED!
#
# Sample ID: 19
# Col: m1, DTW distance: 4.355220026830776, expected limit: 30
# Col: m3, DTW distance: 2.2535331477928335, expected limit: 25
# Col: m12, DTW distance: 1.3182705457019943, expected limit: 15
# Col: e2, DTW distance: 2.1115619983882863, expected limit: 20
# Seed 18 marking 4 as happy from 708 to 730 has been MAINTAINED!
#
# Sample ID: 20
# Col: m1, DTW distance: 4.583830114424195, expected limit: 30
# Col: m3, DTW distance: 2.317948066111195, expected limit: 25
# Col: m12, DTW distance: 2.8456124935627147, expected limit: 15
# Col: e2, DTW distance: 2.184809145277966, expected limit: 20
# Seed 43 marking 4 as happy from 865 to 880 has been MAINTAINED!
#
# Sample ID: 21
# Col: m1, DTW distance: 3.3517970258656526, expected limit: 30
# Col: m3, DTW distance: 2.3345381791003033, expected limit: 25
# Col: m12, DTW distance: 2.3822958889010124, expected limit: 15
# Col: e2, DTW distance: 3.25395567798027, expected limit: 20
# Seed 18 marking 4 as happy from 897 to 919 has been MAINTAINED!
#
# Sample ID: 22
# Col: m1, DTW distance: 3.6758449374448765, expected limit: 30
# Col: m3, DTW distance: 1.6339806546645965, expected limit: 25
# Col: m12, DTW distance: 1.443467824571694, expected limit: 15
# Col: e2, DTW distance: 2.471189254501875, expected limit: 20
# Seed 34 marking 4 as happy from 952 to 965 has been MAINTAINED!
#
# Sample ID: 23
# Col: m1, DTW distance: 4.198795741553591, expected limit: 30
# Col: m3, DTW distance: 2.292590792564907, expected limit: 25
# Col: m12, DTW distance: 4.399513723932269, expected limit: 15
# Col: e2, DTW distance: 2.9299891044664936, expected limit: 20
# Seed 42 marking 4 as happy from 1292 to 1308 has been MAINTAINED!
#
# Sample ID: 24
# Col: m1, DTW distance: 4.656411492079619, expected limit: 30
# Col: m3, DTW distance: 3.383619971745014, expected limit: 25
# Col: m12, DTW distance: 4.809366389369895, expected limit: 15
# Col: e2, DTW distance: 2.801644268974625, expected limit: 20
# Seed 41 marking 4 as happy from 1510 to 1536 has been MAINTAINED!
#
# Sample ID: 25
# Col: m1, DTW distance: 2.488545436503906, expected limit: 30
# Col: m3, DTW distance: 2.032657263018885, expected limit: 25
# Col: m12, DTW distance: 2.472184161236463, expected limit: 15
# Col: e2, DTW distance: 2.401918962576838, expected limit: 20
# Seed 45 marking 4 as happy from 1629 to 1640 has been MAINTAINED!
#
# Sample ID: 26
# Col: m1, DTW distance: 3.77578272136535, expected limit: 30
# Col: m3, DTW distance: 2.1031992423803345, expected limit: 25
# Col: m12, DTW distance: 4.197821642040956, expected limit: 15
# Col: e2, DTW distance: 3.082325123630068, expected limit: 20
# Seed 20 marking 4 as happy from 1708 to 1729 has been MAINTAINED!
#
# Sample ID: 27
# Col: m1, DTW distance: 5.25887980706556, expected limit: 30
# Col: m3, DTW distance: 2.496244412916925, expected limit: 25
# Col: m12, DTW distance: 1.553532351126726, expected limit: 15
# Col: e2, DTW distance: 1.838875739751637, expected limit: 20
# Seed 34 marking 4 as happy from 2846 to 2859 has been MAINTAINED!
#
# Sample ID: 28
# Col: m1, DTW distance: 4.279950000037088, expected limit: 30
# Col: m3, DTW distance: 2.541790074873664, expected limit: 25
# Col: m12, DTW distance: 1.7901542872747327, expected limit: 15
# Col: e2, DTW distance: 2.4810462124789163, expected limit: 20
# Seed 27 marking 4 as happy from 3168 to 3183 has been MAINTAINED!
#
# Sample ID: 29
# Col: m1, DTW distance: 1.369368445267932, expected limit: 30
# Col: m3, DTW distance: 1.56899555056615, expected limit: 25
# Col: m12, DTW distance: 1.1594271366662114, expected limit: 15
# Col: e2, DTW distance: 0.8211140922560619, expected limit: 20
# Seed 38 marking 4 as happy from 3480 to 3490 has been MAINTAINED!
#
# Sample ID: 30
# Col: m1, DTW distance: 3.9816965587360422, expected limit: 30
# Col: m3, DTW distance: 1.7954586658041718, expected limit: 25
# Col: m12, DTW distance: 1.6282877338882225, expected limit: 15
# Col: e2, DTW distance: 2.0826488728231185, expected limit: 20
# Seed 45 marking 4 as happy from 3648 to 3662 has been MAINTAINED!
#
# Sample ID: 31
# Col: m1, DTW distance: 4.450336450854454, expected limit: 30
# Col: m3, DTW distance: 4.578226688591308, expected limit: 25
# Col: m12, DTW distance: 3.433963008902258, expected limit: 15
# Col: e2, DTW distance: 2.172133930049297, expected limit: 20
# Seed 30 marking 4 as happy from 3904 to 3919 has been MAINTAINED!
#
# Sample ID: 32
# Col: m1, DTW distance: 2.7394397496248497, expected limit: 30
# Col: m3, DTW distance: 1.4460880540198529, expected limit: 25
# Col: m12, DTW distance: 2.36569387574237, expected limit: 15
# Col: e2, DTW distance: 2.3918378434214613, expected limit: 20
# Seed 45 marking 4 as happy from 3947 to 3958 has been MAINTAINED!
#
# Sample ID: 33
# Col: m1, DTW distance: 3.5419095822449793, expected limit: 30
# Col: m3, DTW distance: 2.468502884045838, expected limit: 25
# Col: m12, DTW distance: 2.4496402278859093, expected limit: 15
# Col: e2, DTW distance: 2.8340693190821837, expected limit: 20
# Seed 28 marking 4 as happy from 4087 to 4109 has been MAINTAINED!
#
# Sample ID: 34
# Col: m1, DTW distance: 2.645537596217396, expected limit: 30
# Col: m3, DTW distance: 4.3617865663348745, expected limit: 25
# Col: m12, DTW distance: 3.6682683078802834, expected limit: 15
# Col: e2, DTW distance: 2.7620681643226868, expected limit: 20
# Seed 28 marking 4 as happy from 4335 to 4357 has been MAINTAINED!
#
# Sample ID: 35
# Col: m1, DTW distance: 5.7694578908283916, expected limit: 30
# Col: m3, DTW distance: 2.038462821903225, expected limit: 25
# Col: m12, DTW distance: 3.856790590826494, expected limit: 15
# Col: e2, DTW distance: 2.21693307945993, expected limit: 20
# Seed 43 marking 4 as happy from 4411 to 4426 has been MAINTAINED!
#
# Sample ID: 36
# Col: m1, DTW distance: 4.044322883258821, expected limit: 30
# Col: m3, DTW distance: 1.453327534918367, expected limit: 25
# Col: m12, DTW distance: 2.362300007954295, expected limit: 15
# Col: e2, DTW distance: 1.785132383187468, expected limit: 20
# Seed 43 marking 4 as happy from 4451 to 4466 has been MAINTAINED!
#
# Sample ID: 37
# Col: m1, DTW distance: 3.5408324609917505, expected limit: 30
# Col: m3, DTW distance: 2.2288687869373014, expected limit: 25
# Col: m12, DTW distance: 5.107168467788232, expected limit: 15
# Col: e2, DTW distance: 1.4989175587465058, expected limit: 20
# Seed 34 marking 4 as happy from 4862 to 4875 has been MAINTAINED!
#
# Sample ID: 38
# Col: m1, DTW distance: 5.469921496433317, expected limit: 30
# Col: m3, DTW distance: 1.1877344108318038, expected limit: 25
# Col: m12, DTW distance: 1.887869971228107, expected limit: 15
# Col: e2, DTW distance: 0.9807056840972469, expected limit: 20
# Seed 29 marking 5 as happy from 1762 to 1773 has been MAINTAINED!
#
# Sample ID: 39
# Col: m1, DTW distance: 4.096169779727647, expected limit: 30
# Col: m3, DTW distance: 2.8052795346718384, expected limit: 25
# Col: m12, DTW distance: 5.701604341616621, expected limit: 15
# Col: e2, DTW distance: 2.2951940582638715, expected limit: 20
# Seed 43 marking 5 as happy from 2081 to 2096 has been MAINTAINED!
#
# Sample ID: 40
# Col: m1, DTW distance: 2.75487053991018, expected limit: 30
# Col: m3, DTW distance: 1.4578548810392096, expected limit: 25
# Col: m12, DTW distance: 2.22610595269142, expected limit: 15
# Col: e2, DTW distance: 2.505190193861854, expected limit: 20
# Seed 37 marking 5 as happy from 2443 to 2452 has been MAINTAINED!
#
# Sample ID: 41
# Col: m1, DTW distance: 1.8872350601903574, expected limit: 30
# Col: m3, DTW distance: 1.4122301731842755, expected limit: 25
# Col: m12, DTW distance: 1.3345692420320021, expected limit: 15
# Col: e2, DTW distance: 2.0475771400991216, expected limit: 20
# Seed 37 marking 5 as happy from 3060 to 3069 has been MAINTAINED!
#
# Sample ID: 42
# Col: m1, DTW distance: 4.822092741818076, expected limit: 30
# Col: m3, DTW distance: 2.9367896273656346, expected limit: 25
# Col: m12, DTW distance: 2.492551325802937, expected limit: 15
# Col: e2, DTW distance: 3.5266766695876974, expected limit: 20
# Seed 32 marking 5 as happy from 3615 to 3641 has been MAINTAINED!
#
# Sample ID: 43
# Col: m1, DTW distance: 3.523782853701861, expected limit: 30
# Col: m3, DTW distance: 1.6830846861007114, expected limit: 25
# Col: m12, DTW distance: 1.447113086374845, expected limit: 15
# Col: e2, DTW distance: 2.1469609308824147, expected limit: 20
# Seed 30 marking 6 as happy from 1354 to 1369 has been MAINTAINED!
#
# Sample ID: 44
# Col: m1, DTW distance: 4.779424262615396, expected limit: 30
# Col: m3, DTW distance: 2.246348511478708, expected limit: 25
# Col: m12, DTW distance: 1.554205495037578, expected limit: 15
# Col: e2, DTW distance: 2.053441383019895, expected limit: 20
# Seed 27 marking 6 as happy from 1774 to 1790 has been MAINTAINED!
#
# Sample ID: 45
# Col: m1, DTW distance: 6.220204601975713, expected limit: 30
# Col: m3, DTW distance: 1.1455307719530412, expected limit: 25
# Col: m12, DTW distance: 2.278280730933858, expected limit: 15
# Col: e2, DTW distance: 2.342784833248032, expected limit: 20
# Seed 38 marking 6 as happy from 3086 to 3100 has been MAINTAINED!
#
# Sample ID: 46
# Col: m1, DTW distance: 2.9278741962455133, expected limit: 30
# Col: m3, DTW distance: 2.5611886109770667, expected limit: 25
# Col: m12, DTW distance: 3.1858719825682593, expected limit: 15
# Col: e2, DTW distance: 1.6882198533562558, expected limit: 20
# Seed 29 marking 6 as happy from 3337 to 3348 has been MAINTAINED!
#
# Sample ID: 47
# Col: m1, DTW distance: 2.7256346396181756, expected limit: 30
# Col: m3, DTW distance: 1.7932737018188776, expected limit: 25
# Col: m12, DTW distance: 1.9193389658787126, expected limit: 15
# Col: e2, DTW distance: 2.146525007620636, expected limit: 20
# Seed 43 marking 6 as happy from 3885 to 3900 has been MAINTAINED!
#
# Sample ID: 48
# Col: m1, DTW distance: 3.186596122904799, expected limit: 30
# Col: m3, DTW distance: 1.596559302916367, expected limit: 25
# Col: m12, DTW distance: 0.815805553813222, expected limit: 15
# Col: e2, DTW distance: 2.345801577925458, expected limit: 20
# Seed 19 marking 6 as happy from 4049 to 4062 has been MAINTAINED!
#
# Sample ID: 49
# Col: m1, DTW distance: 3.194373319824349, expected limit: 30
# Col: m3, DTW distance: 2.4343443789715247, expected limit: 25
# Col: m12, DTW distance: 2.7664774510024306, expected limit: 15
# Col: e2, DTW distance: 1.8087295544797142, expected limit: 20
# Seed 44 marking 7 as happy from 1435 to 1449 has been MAINTAINED!
#
# Sample ID: 50
# Col: m1, DTW distance: 2.355702275850343, expected limit: 30
# Col: m3, DTW distance: 1.866730117287647, expected limit: 25
# Col: m12, DTW distance: 4.479327142960174, expected limit: 15
# Col: e2, DTW distance: 3.706416864743955, expected limit: 20
# Seed 20 marking 7 as happy from 1920 to 1941 has been MAINTAINED!
#
# Sample ID: 51
# Col: m1, DTW distance: 2.494967302836694, expected limit: 30
# Col: m3, DTW distance: 1.3825333187159097, expected limit: 25
# Col: m12, DTW distance: 1.6477299559313376, expected limit: 15
# Col: e2, DTW distance: 2.5291228585755254, expected limit: 20
# Seed 29 marking 7 as happy from 3404 to 3415 has been MAINTAINED!
#
# Sample ID: 52
# Col: m1, DTW distance: 2.9854781974905724, expected limit: 30
# Col: m3, DTW distance: 3.209649608730621, expected limit: 25
# Col: m12, DTW distance: 1.9495840820505022, expected limit: 15
# Col: e2, DTW distance: 2.7511627650561516, expected limit: 20
# Seed 45 marking 7 as happy from 3933 to 3944 has been MAINTAINED!
#
# Sample ID: 53
# Col: m1, DTW distance: 2.9996721637055024, expected limit: 30
# Col: m3, DTW distance: 1.4951873029339562, expected limit: 25
# Col: m12, DTW distance: 2.4007811147725833, expected limit: 15
# Col: e2, DTW distance: 3.161453058440433, expected limit: 20
# Seed 17 marking 8 as happy from 648 to 668 has been MAINTAINED!
#
# Sample ID: 54
# Col: m1, DTW distance: 5.415261575388391, expected limit: 30
# Col: m3, DTW distance: 1.98197052887513, expected limit: 25
# Col: m12, DTW distance: 2.678187240221281, expected limit: 15
# Col: e2, DTW distance: 2.315049029960877, expected limit: 20
# Seed 33 marking 8 as happy from 1542 to 1561 has been MAINTAINED!
#
# Sample ID: 55
# Col: m1, DTW distance: 6.577008642386397, expected limit: 30
# Col: m3, DTW distance: 1.8759872694490423, expected limit: 25
# Col: m12, DTW distance: 3.1116797903809355, expected limit: 15
# Col: e2, DTW distance: 2.6107267504010836, expected limit: 20
# Seed 43 marking 8 as happy from 1958 to 1973 has been MAINTAINED!
#
# Sample ID: 56
# Col: m1, DTW distance: 3.2809349419295946, expected limit: 30
# Col: m3, DTW distance: 1.1967359988924746, expected limit: 25
# Col: m12, DTW distance: 1.3794199080662317, expected limit: 15
# Col: e2, DTW distance: 2.440422183085038, expected limit: 20
# Seed 27 marking 8 as happy from 2955 to 2970 has been MAINTAINED!
#
# Sample ID: 57
# Col: m1, DTW distance: 5.088635900710987, expected limit: 30
# Col: m3, DTW distance: 1.5741755837603975, expected limit: 25
# Col: m12, DTW distance: 1.4170193864037846, expected limit: 15
# Col: e2, DTW distance: 4.1608951794005495, expected limit: 20
# Seed 45 marking 8 as happy from 3216 to 3227 has been MAINTAINED!
#
# Sample ID: 58
# Col: m1, DTW distance: 3.4846254252510764, expected limit: 30
# Col: m3, DTW distance: 1.1268331016171238, expected limit: 25
# Col: m12, DTW distance: 3.1498742338658383, expected limit: 15
# Col: e2, DTW distance: 3.313861196595259, expected limit: 20
# Seed 33 marking 9 as happy from 761 to 780 has been MAINTAINED!
#
# Sample ID: 59
# Col: m1, DTW distance: 3.7485540773564034, expected limit: 30
# Col: m3, DTW distance: 3.131095821314818, expected limit: 25
# Col: m12, DTW distance: 2.247119936784151, expected limit: 15
# Col: e2, DTW distance: 2.101363088977378, expected limit: 20
# Seed 23 marking 9 as happy from 1630 to 1649 has been MAINTAINED!
#
# Sample ID: 60
# Col: m1, DTW distance: 1.4018268364006776, expected limit: 30
# Col: m3, DTW distance: 2.4972181194190606, expected limit: 25
# Col: m12, DTW distance: 1.7012030016590385, expected limit: 15
# Col: e2, DTW distance: 4.757643125475317, expected limit: 20
# Seed 16 marking 9 as happy from 2440 to 2460 has been MAINTAINED!
#
# Sample ID: 61
# Col: m1, DTW distance: 2.3926208220430745, expected limit: 30
# Col: m3, DTW distance: 2.125694565917863, expected limit: 25
# Col: m12, DTW distance: 1.8124546085051094, expected limit: 15
# Col: e2, DTW distance: 3.105067309795177, expected limit: 20
# Seed 38 marking 9 as happy from 5525 to 5546 has been MAINTAINED!
#
# Sample ID: 62
# Col: m1, DTW distance: 2.240116974416596, expected limit: 30
# Col: m3, DTW distance: 2.646445732001935, expected limit: 25
# Col: m12, DTW distance: 3.209509055513473, expected limit: 15
# Col: e2, DTW distance: 2.5891603044801434, expected limit: 20
# Seed 25 marking 10 as happy from 1945 to 1972 has been MAINTAINED!
#
# Sample ID: 63
# Col: m1, DTW distance: 4.930082292599607, expected limit: 30
# Col: m3, DTW distance: 4.766515600732236, expected limit: 25
# Col: m12, DTW distance: 1.6500340671620977, expected limit: 15
# Col: e2, DTW distance: 3.49135549993483, expected limit: 20
# Seed 21 marking 11 as happy from 917 to 935 has been MAINTAINED!
#
# Sample ID: 64
# Col: m1, DTW distance: 3.3990282266304974, expected limit: 30
# Col: m3, DTW distance: 1.6949021768441068, expected limit: 25
# Col: m12, DTW distance: 2.0127728743171356, expected limit: 15
# Col: e2, DTW distance: 1.4807168114142506, expected limit: 20
# Seed 38 marking 11 as happy from 1438 to 1448 has been MAINTAINED!
#
# Sample ID: 65
# Col: m1, DTW distance: 7.550532816673187, expected limit: 30
# Col: m3, DTW distance: 2.534337460188333, expected limit: 25
# Col: m12, DTW distance: 1.9436590679910593, expected limit: 15
# Col: e2, DTW distance: 2.9113636369524705, expected limit: 20
# Seed 44 marking 11 as happy from 1506 to 1520 has been MAINTAINED!
#
# Sample ID: 66
# Col: m1, DTW distance: 4.950582771552987, expected limit: 30
# Col: m3, DTW distance: 2.3422818886849246, expected limit: 25
# Col: m12, DTW distance: 3.595771004883757, expected limit: 15
# Col: e2, DTW distance: 2.9055681152691113, expected limit: 20
# Seed 21 marking 11 as happy from 1904 to 1922 has been MAINTAINED!
#
# Sample ID: 67
# Col: m1, DTW distance: 5.7116505175986365, expected limit: 30
# Col: m3, DTW distance: 3.1023399587478204, expected limit: 25
# Col: m12, DTW distance: 2.101559936466094, expected limit: 15
# Col: e2, DTW distance: 3.5379092526606066, expected limit: 20
# Seed 44 marking 11 as happy from 2114 to 2128 has been MAINTAINED!
#
# Sample ID: 68
# Col: m1, DTW distance: 6.358362890594849, expected limit: 30
# Col: m3, DTW distance: 3.915892166700131, expected limit: 25
# Col: m12, DTW distance: 2.2017878451302986, expected limit: 15
# Col: e2, DTW distance: 4.074943726980273, expected limit: 20
# Seed 28 marking 11 as happy from 2529 to 2557 has been MAINTAINED!
#
# Sample ID: 69
# Col: m1, DTW distance: 6.585484983877856, expected limit: 30
# Col: m3, DTW distance: 2.713968817910731, expected limit: 25
# Col: m12, DTW distance: 3.3374638164805615, expected limit: 15
# Col: e2, DTW distance: 3.1795680008555416, expected limit: 20
# Seed 44 marking 11 as happy from 2596 to 2610 has been MAINTAINED!
#
# Sample ID: 70
# Col: m1, DTW distance: 4.428053979974515, expected limit: 30
# Col: m3, DTW distance: 3.7863555344846436, expected limit: 25
# Col: m12, DTW distance: 2.10116406205639, expected limit: 15
# Col: e2, DTW distance: 2.213932739049925, expected limit: 20
# Seed 27 marking 11 as happy from 3088 to 3107 has been MAINTAINED!
#
# Sample ID: 71
# Col: m1, DTW distance: 3.287838055259305, expected limit: 30
# Col: m3, DTW distance: 2.9788390047047435, expected limit: 25
# Col: m12, DTW distance: 3.158465810110487, expected limit: 15
# Col: e2, DTW distance: 3.0719968768556587, expected limit: 20
# Seed 29 marking 11 as happy from 3376 to 3401 has been MAINTAINED!
#
# Sample ID: 72
# Col: m1, DTW distance: 4.033486143599815, expected limit: 30
# Col: m3, DTW distance: 3.0064235726518365, expected limit: 25
# Col: m12, DTW distance: 2.9163419485730198, expected limit: 15
# Col: e2, DTW distance: 1.9103161815291196, expected limit: 20
# Seed 27 marking 11 as happy from 3606 to 3621 has been MAINTAINED!
#
# Sample ID: 73
# Col: m1, DTW distance: 4.239205178205083, expected limit: 30
# Col: m3, DTW distance: 4.548533108617662, expected limit: 25
# Col: m12, DTW distance: 4.110470207113914, expected limit: 15
# Col: e2, DTW distance: 1.6850762012382865, expected limit: 20
# Seed 20 marking 11 as happy from 4405 to 4426 has been MAINTAINED!
#
# Sample ID: 74
# Col: m1, DTW distance: 5.558340655292661, expected limit: 30
# Col: m3, DTW distance: 3.9271498691277893, expected limit: 25
# Col: m12, DTW distance: 2.881258541493915, expected limit: 15
# Col: e2, DTW distance: 2.6271446915089123, expected limit: 20
# Seed 41 marking 12 as happy from 477 to 501 has been MAINTAINED!
#
# Sample ID: 75
# Col: m1, DTW distance: 4.524079316969855, expected limit: 30
# Col: m3, DTW distance: 5.544367561383902, expected limit: 25
# Col: m12, DTW distance: 2.7187178821923923, expected limit: 15
# Col: e2, DTW distance: 2.1070664808156647, expected limit: 20
# Seed 23 marking 12 as happy from 509 to 528 has been MAINTAINED!
#
# Sample ID: 76
# Col: m1, DTW distance: 4.589542531425227, expected limit: 30
# Col: m3, DTW distance: 3.128431210542155, expected limit: 25
# Col: m12, DTW distance: 2.0379561501077545, expected limit: 15
# Col: e2, DTW distance: 1.840410667639631, expected limit: 20
# Seed 30 marking 12 as happy from 655 to 670 has been MAINTAINED!
#
# Sample ID: 77
# Col: m1, DTW distance: 2.2844508955030074, expected limit: 30
# Col: m3, DTW distance: 1.630881612015933, expected limit: 25
# Col: m12, DTW distance: 4.816510501043967, expected limit: 15
# Col: e2, DTW distance: 2.455421048887144, expected limit: 20
# Seed 43 marking 12 as happy from 1668 to 1683 has been MAINTAINED!
#
# Sample ID: 78
# Col: m1, DTW distance: 5.851132801967894, expected limit: 30
# Col: m3, DTW distance: 2.341023255039916, expected limit: 25
# Col: m12, DTW distance: 3.276643986803683, expected limit: 15
# Col: e2, DTW distance: 2.763152348643812, expected limit: 20
# Seed 44 marking 12 as happy from 2355 to 2369 has been MAINTAINED!
#
# Sample ID: 79
# Col: m1, DTW distance: 2.655438882488351, expected limit: 30
# Col: m3, DTW distance: 3.7178194142989236, expected limit: 25
# Col: m12, DTW distance: 3.320702173975884, expected limit: 15
# Col: e2, DTW distance: 3.07740927609557, expected limit: 20
# Seed 20 marking 12 as happy from 2374 to 2395 has been MAINTAINED!
#
# Sample ID: 80
# Col: m1, DTW distance: 3.5709233633085864, expected limit: 30
# Col: m3, DTW distance: 2.121707814136183, expected limit: 25
# Col: m12, DTW distance: 1.4252251928514983, expected limit: 15
# Col: e2, DTW distance: 3.5356313701654263, expected limit: 20
# Seed 21 marking 12 as happy from 2654 to 2672 has been MAINTAINED!
#
# Sample ID: 81
# Col: m1, DTW distance: 3.749488292822857, expected limit: 30
# Col: m3, DTW distance: 3.390182525261551, expected limit: 25
# Col: m12, DTW distance: 3.787325163918215, expected limit: 15
# Col: e2, DTW distance: 2.2864718839463696, expected limit: 20
# Seed 42 marking 13 as happy from 323 to 339 has been MAINTAINED!
#
# Sample ID: 82
# Col: m1, DTW distance: 5.617702240270112, expected limit: 30
# Col: m3, DTW distance: 1.593823161135542, expected limit: 25
# Col: m12, DTW distance: 2.26797822182127, expected limit: 15
# Col: e2, DTW distance: 2.7567557103115274, expected limit: 20
# Seed 38 marking 13 as happy from 1378 to 1388 has been MAINTAINED!
#
# Sample ID: 83
# Col: m1, DTW distance: 3.524925219656787, expected limit: 30
# Col: m3, DTW distance: 4.608437412895104, expected limit: 25
# Col: m12, DTW distance: 3.7266640647407523, expected limit: 15
# Col: e2, DTW distance: 2.828405768192041, expected limit: 20
# Seed 20 marking 13 as happy from 1529 to 1550 has been MAINTAINED!
#
# Sample ID: 84
# Col: m1, DTW distance: 2.4698964762878988, expected limit: 30
# Col: m3, DTW distance: 1.720190454039736, expected limit: 25
# Col: m12, DTW distance: 0.7933564392737813, expected limit: 15
# Col: e2, DTW distance: 3.1899334587438415, expected limit: 20
# Seed 18 marking 13 as happy from 2635 to 2657 has been MAINTAINED!
#
# Sample ID: 85
# Col: m1, DTW distance: 5.728425384159081, expected limit: 30
# Col: m3, DTW distance: 1.5031653591827356, expected limit: 25
# Col: m12, DTW distance: 1.7744082298760686, expected limit: 15
# Col: e2, DTW distance: 1.8208054304583527, expected limit: 20
# Seed 29 marking 13 as happy from 4840 to 4851 has been MAINTAINED!
#
# Sample ID: 86
# Col: m1, DTW distance: 2.7959772343688356, expected limit: 30
# Col: m3, DTW distance: 3.643269579330834, expected limit: 25
# Col: m12, DTW distance: 2.2652737006742103, expected limit: 15
# Col: e2, DTW distance: 1.274855920835533, expected limit: 20
# Seed 43 marking 13 as happy from 4968 to 4983 has been MAINTAINED!
#
# Sample ID: 87
# Col: m1, DTW distance: 5.7760377325665155, expected limit: 30
# Col: m3, DTW distance: 3.0775020847810146, expected limit: 25
# Col: m12, DTW distance: 2.0746454455516985, expected limit: 15
# Col: e2, DTW distance: 1.6131212563320938, expected limit: 20
# Seed 44 marking 13 as happy from 5342 to 5356 has been MAINTAINED!
#
# Sample ID: 88
# Col: m1, DTW distance: 3.913760935277581, expected limit: 30
# Col: m3, DTW distance: 1.157530866984308, expected limit: 25
# Col: m12, DTW distance: 1.4935682527044738, expected limit: 15
# Col: e2, DTW distance: 2.1055151184311414, expected limit: 20
# Seed 45 marking 13 as happy from 5772 to 5783 has been MAINTAINED!
#
# Sample ID: 89
# Col: m1, DTW distance: 4.509860834401016, expected limit: 30
# Col: m3, DTW distance: 2.9020074128360864, expected limit: 25
# Col: m12, DTW distance: 1.6910711770630693, expected limit: 15
# Col: e2, DTW distance: 2.1381355319462254, expected limit: 20
# Seed 31 marking 13 as happy from 5928 to 5947 has been MAINTAINED!
#
# Sample ID: 90
# Col: m1, DTW distance: 0.7806218632214024, expected limit: 30
# Col: m3, DTW distance: 1.3280888224266731, expected limit: 25
# Col: m12, DTW distance: 4.365087067619056, expected limit: 15
# Col: e2, DTW distance: 1.9069075786969345, expected limit: 20
# Seed 43 marking 13 as happy from 6025 to 6040 has been MAINTAINED!
#
# Sample ID: 91
# Col: m1, DTW distance: 2.861744735211579, expected limit: 30
# Col: m3, DTW distance: 2.068143249065992, expected limit: 25
# Col: m12, DTW distance: 2.9038938568854626, expected limit: 15
# Col: e2, DTW distance: 1.7752154981904544, expected limit: 20
# Seed 38 marking 13 as happy from 7309 to 7319 has been MAINTAINED!
#
# Sample ID: 92
# Col: m1, DTW distance: 5.574721465688678, expected limit: 30
# Col: m3, DTW distance: 3.527557001527348, expected limit: 25
# Col: m12, DTW distance: 3.1991211368022197, expected limit: 15
# Col: e2, DTW distance: 2.302796798026053, expected limit: 20
# Seed 33 marking 13 as happy from 7522 to 7541 has been MAINTAINED!
#
# Sample ID: 93
# Col: m1, DTW distance: 5.2925761864471434, expected limit: 30
# Col: m3, DTW distance: 6.243705516819194, expected limit: 25
# Col: m12, DTW distance: 4.118083479519908, expected limit: 15
# Col: e2, DTW distance: 2.1275140091098175, expected limit: 20
# Seed 44 marking 13 as happy from 7849 to 7863 has been MAINTAINED!
#
# Sample ID: 94
# Col: m1, DTW distance: 5.373207987140667, expected limit: 30
# Col: m3, DTW distance: 1.935568539405655, expected limit: 25
# Col: m12, DTW distance: 3.3886448922397205, expected limit: 15
# Col: e2, DTW distance: 2.3738498634322855, expected limit: 20
# Seed 43 marking 13 as happy from 7942 to 7957 has been MAINTAINED!
#
# Sample ID: 95
# Col: m1, DTW distance: 5.405788959251909, expected limit: 30
# Col: m3, DTW distance: 4.281302191423987, expected limit: 25
# Col: m12, DTW distance: 2.360877729125746, expected limit: 15
# Col: e2, DTW distance: 3.7635463051109777, expected limit: 20
# Seed 32 marking 13 as happy from 8252 to 8278 has been MAINTAINED!
#
# Sample ID: 96
# Col: m1, DTW distance: 4.502113532559706, expected limit: 30
# Col: m3, DTW distance: 3.7762005970657793, expected limit: 25
# Col: m12, DTW distance: 3.160585848504978, expected limit: 15
# Col: e2, DTW distance: 2.2186777781184075, expected limit: 20
# Seed 20 marking 13 as happy from 8579 to 8600 has been MAINTAINED!
#
# Sample ID: 97
# Col: m1, DTW distance: 4.792369229252091, expected limit: 30
# Col: m3, DTW distance: 1.1404384929952736, expected limit: 25
# Col: m12, DTW distance: 4.280463168907481, expected limit: 15
# Col: e2, DTW distance: 3.44508130009155, expected limit: 20
# Seed 42 marking 13 as happy from 8639 to 8655 has been MAINTAINED!
#
# Sample ID: 98
# Col: m1, DTW distance: 2.3880759668909857, expected limit: 30
# Col: m3, DTW distance: 1.2602409681602165, expected limit: 25
# Col: m12, DTW distance: 0.8839622782428206, expected limit: 15
# Col: e2, DTW distance: 1.4759705420517786, expected limit: 20
# Seed 37 marking 14 as happy from 810 to 819 has been MAINTAINED!
#
# Sample ID: 99
# Col: m1, DTW distance: 3.9516530670903824, expected limit: 30
# Col: m3, DTW distance: 1.0750861353167098, expected limit: 25
# Col: m12, DTW distance: 1.2062935666083032, expected limit: 15
# Col: e2, DTW distance: 1.5749418692148192, expected limit: 20
# Seed 27 marking 14 as happy from 894 to 909 has been MAINTAINED!
#
# Sample ID: 100
# Col: m1, DTW distance: 4.804896776661196, expected limit: 30
# Col: m3, DTW distance: 2.4259124114731834, expected limit: 25
# Col: m12, DTW distance: 3.2870226240994516, expected limit: 15
# Col: e2, DTW distance: 2.3141476005188366, expected limit: 20
# Seed 23 marking 14 as happy from 1606 to 1625 has been MAINTAINED!
#
# Sample ID: 101
# Col: m1, DTW distance: 1.9840763235216077, expected limit: 30
# Col: m3, DTW distance: 1.1626221593788908, expected limit: 25
# Col: m12, DTW distance: 0.7165956158798669, expected limit: 15
# Col: e2, DTW distance: 1.7330922805747904, expected limit: 20
# Seed 37 marking 15 as happy from 1381 to 1390 has been MAINTAINED!
#
# Sample ID: 102
# Col: m1, DTW distance: 5.716274713081539, expected limit: 30
# Col: m3, DTW distance: 5.564422530531972, expected limit: 25
# Col: m12, DTW distance: 3.165128595026295, expected limit: 15
# Col: e2, DTW distance: 2.1526741382839836, expected limit: 20
# Seed 29 marking 15 as happy from 2014 to 2025 has been MAINTAINED!
#
# Sample ID: 103
# Col: m1, DTW distance: 4.967140126149342, expected limit: 30
# Col: m3, DTW distance: 1.6816634681595275, expected limit: 25
# Col: m12, DTW distance: 1.396261853677865, expected limit: 15
# Col: e2, DTW distance: 4.374188804437735, expected limit: 20
# Seed 26 marking 15 as happy from 2690 to 2715 has been MAINTAINED!
#
# Sample ID: 104
# Col: m1, DTW distance: 3.035405874502126, expected limit: 30
# Col: m3, DTW distance: 1.9996419860383332, expected limit: 25
# Col: m12, DTW distance: 2.0082429151183403, expected limit: 15
# Col: e2, DTW distance: 2.684101177192012, expected limit: 20
# Seed 44 marking 15 as happy from 2809 to 2823 has been MAINTAINED!
#
# Sample ID: 105
# Col: m1, DTW distance: 3.0565215020816408, expected limit: 30
# Col: m3, DTW distance: 1.2369159110379815, expected limit: 25
# Col: m12, DTW distance: 1.4350949147768521, expected limit: 15
# Col: e2, DTW distance: 2.501055015365314, expected limit: 20
# Seed 31 marking 15 as happy from 3144 to 3163 has been MAINTAINED!
#
# Sample ID: 106
# Col: m1, DTW distance: 1.7054214237480416, expected limit: 30
# Col: m3, DTW distance: 0.7441457383706926, expected limit: 25
# Col: m12, DTW distance: 1.6041105224397956, expected limit: 15
# Col: e2, DTW distance: 2.6728782766604624, expected limit: 20
# Seed 44 marking 15 as happy from 3469 to 3483 has been MAINTAINED!
#
# Sample ID: 107
# Col: m1, DTW distance: 3.640525687596818, expected limit: 30
# Col: m3, DTW distance: 1.229331780240068, expected limit: 25
# Col: m12, DTW distance: 1.6295248994693532, expected limit: 15
# Col: e2, DTW distance: 1.0147032069875366, expected limit: 20
# Seed 38 marking 15 as happy from 3695 to 3705 has been MAINTAINED!
#
# Sample ID: 108
# Col: m1, DTW distance: 4.633759739561027, expected limit: 30
# Col: m3, DTW distance: 0.9352658813563078, expected limit: 25
# Col: m12, DTW distance: 0.827643873488479, expected limit: 15
# Col: e2, DTW distance: 2.8025439061122785, expected limit: 20
# Seed 19 marking 15 as happy from 5312 to 5325 has been MAINTAINED!
#
# Sample ID: 109
# Col: m1, DTW distance: 4.019394362736115, expected limit: 30
# Col: m3, DTW distance: 2.540482817837865, expected limit: 25
# Col: m12, DTW distance: 1.6189726747659605, expected limit: 15
# Col: e2, DTW distance: 1.9648184945774592, expected limit: 20
# Seed 31 marking 15 as happy from 5478 to 5497 has been MAINTAINED!
#
# Sample ID: 110
# Col: m1, DTW distance: 1.3865803963513252, expected limit: 30
# Col: m3, DTW distance: 3.088472629655716, expected limit: 25
# Col: m12, DTW distance: 1.306093034334593, expected limit: 15
# Col: e2, DTW distance: 1.8688455181435686, expected limit: 20
# Seed 22 marking 15 as happy from 5816 to 5840 has been MAINTAINED!
#
# Sample ID: 111
# Col: m1, DTW distance: 7.359685657672918, expected limit: 30
# Col: m3, DTW distance: 1.8726392396191156, expected limit: 25
# Col: m12, DTW distance: 1.1836936742994988, expected limit: 15
# Col: e2, DTW distance: 2.1255258524815503, expected limit: 20
# Seed 18 marking 16 as happy from 783 to 805 has been MAINTAINED!
#
# Sample ID: 112
# Col: m1, DTW distance: 3.2649357546160847, expected limit: 30
# Col: m3, DTW distance: 1.299094318038635, expected limit: 25
# Col: m12, DTW distance: 1.200782040723169, expected limit: 15
# Col: e2, DTW distance: 2.982093325569211, expected limit: 20
# Seed 18 marking 16 as happy from 1102 to 1124 has been MAINTAINED!
#
# Sample ID: 113
# Col: m1, DTW distance: 4.7420765922448025, expected limit: 30
# Col: m3, DTW distance: 1.430762274409084, expected limit: 25
# Col: m12, DTW distance: 2.4966382637677245, expected limit: 15
# Col: e2, DTW distance: 2.51588541046504, expected limit: 20
# Seed 44 marking 16 as happy from 1406 to 1420 has been MAINTAINED!
#
# Sample ID: 114
# Col: m1, DTW distance: 3.99437489445486, expected limit: 30
# Col: m3, DTW distance: 1.9507982384091882, expected limit: 25
# Col: m12, DTW distance: 3.0947715932321427, expected limit: 15
# Col: e2, DTW distance: 3.022608639812629, expected limit: 20
# Seed 44 marking 16 as happy from 1669 to 1683 has been MAINTAINED!
#
# Sample ID: 115
# Col: m1, DTW distance: 5.143444976086788, expected limit: 30
# Col: m3, DTW distance: 0.8711087966618681, expected limit: 25
# Col: m12, DTW distance: 0.7289688090099257, expected limit: 15
# Col: e2, DTW distance: 2.27533325628804, expected limit: 20
# Seed 19 marking 16 as happy from 1952 to 1965 has been MAINTAINED!
#
# Sample ID: 116
# Col: m1, DTW distance: 5.064460154773862, expected limit: 30
# Col: m3, DTW distance: 1.059986067487603, expected limit: 25
# Col: m12, DTW distance: 2.1097466005320595, expected limit: 15
# Col: e2, DTW distance: 1.7492670642901782, expected limit: 20
# Seed 37 marking 16 as happy from 2110 to 2121 has been MAINTAINED!
#
# Sample ID: 117
# Col: m1, DTW distance: 3.214239716217906, expected limit: 30
# Col: m3, DTW distance: 2.0334811869733005, expected limit: 25
# Col: m12, DTW distance: 2.8361283635861163, expected limit: 15
# Col: e2, DTW distance: 1.7875866775208928, expected limit: 20
# Seed 38 marking 16 as happy from 2773 to 2783 has been MAINTAINED!
#
# Sample ID: 118
# Col: m1, DTW distance: 2.6185230836525872, expected limit: 30
# Col: m3, DTW distance: 1.9926162061150827, expected limit: 25
# Col: m12, DTW distance: 0.7210134988204862, expected limit: 15
# Col: e2, DTW distance: 2.789721718010375, expected limit: 20
# Seed 19 marking 16 as happy from 3010 to 3023 has been MAINTAINED!
#
# Sample ID: 119
# Col: m1, DTW distance: 4.420577465907091, expected limit: 30
# Col: m3, DTW distance: 2.3749682583171277, expected limit: 25
# Col: m12, DTW distance: 2.420279675957309, expected limit: 15
# Col: e2, DTW distance: 2.882010680521281, expected limit: 20
# Seed 25 marking 16 as happy from 3097 to 3124 has been MAINTAINED!
#
# Sample ID: 120
# Col: m1, DTW distance: 3.746177086030276, expected limit: 30
# Col: m3, DTW distance: 1.6478677833929323, expected limit: 25
# Col: m12, DTW distance: 0.7415930248904194, expected limit: 15
# Col: e2, DTW distance: 1.1914959333329729, expected limit: 20
# Seed 37 marking 16 as happy from 3136 to 3145 has been MAINTAINED!
#
# Sample ID: 121
# Col: m1, DTW distance: 5.3996319224610145, expected limit: 30
# Col: m3, DTW distance: 1.7772465240764992, expected limit: 25
# Col: m12, DTW distance: 1.4961587556535487, expected limit: 15
# Col: e2, DTW distance: 3.2997733716237434, expected limit: 20
# Seed 44 marking 16 as happy from 3565 to 3579 has been MAINTAINED!
#
# Sample ID: 122
# Col: m1, DTW distance: 1.9525633745454898, expected limit: 30
# Col: m3, DTW distance: 0.7348811478420942, expected limit: 25
# Col: m12, DTW distance: 0.6958053977042076, expected limit: 15
# Col: e2, DTW distance: 1.5693483239040447, expected limit: 20
# Seed 37 marking 16 as happy from 3657 to 3666 has been MAINTAINED!
#
# Sample ID: 123
# Col: m1, DTW distance: 4.744038114548271, expected limit: 30
# Col: m3, DTW distance: 3.6417511567284575, expected limit: 25
# Col: m12, DTW distance: 2.4963583312272934, expected limit: 15
# Col: e2, DTW distance: 2.5687376859578546, expected limit: 20
# Seed 39 marking 16 as happy from 4199 to 4223 has been MAINTAINED!
#
# Sample ID: 124
# Col: m1, DTW distance: 2.805307675415241, expected limit: 30
# Col: m3, DTW distance: 1.1788229054741426, expected limit: 25
# Col: m12, DTW distance: 1.5408996349863433, expected limit: 15
# Col: e2, DTW distance: 3.0776365359171787, expected limit: 20
# Seed 19 marking 16 as happy from 4984 to 4997 has been MAINTAINED!
#
# Sample ID: 125
# Col: m1, DTW distance: 2.891665094294451, expected limit: 30
# Col: m3, DTW distance: 3.1933899713398715, expected limit: 25
# Col: m12, DTW distance: 1.7787245255308708, expected limit: 15
# Col: e2, DTW distance: 1.968031244417481, expected limit: 20
# Seed 22 marking 17 as happy from 728 to 752 has been MAINTAINED!
#
# Sample ID: 126
# Col: m1, DTW distance: 2.606951020140403, expected limit: 30
# Col: m3, DTW distance: 2.679903617643835, expected limit: 25
# Col: m12, DTW distance: 0.9391244752139257, expected limit: 15
# Col: e2, DTW distance: 3.195381088075444, expected limit: 20
# Seed 37 marking 17 as happy from 839 to 848 has been MAINTAINED!
#
# Sample ID: 127
# Col: m1, DTW distance: 5.59403056518982, expected limit: 30
# Col: m3, DTW distance: 4.140265148402121, expected limit: 25
# Col: m12, DTW distance: 3.355247985131887, expected limit: 15
# Col: e2, DTW distance: 2.6542825939622996, expected limit: 20
# Seed 44 marking 17 as happy from 1241 to 1255 has been MAINTAINED!
#
# Sample ID: 128
# Col: m1, DTW distance: 3.3556175501072842, expected limit: 30
# Col: m3, DTW distance: 2.9771788862915063, expected limit: 25
# Col: m12, DTW distance: 3.996943244057745, expected limit: 15
# Col: e2, DTW distance: 2.152453373527522, expected limit: 20
# Seed 43 marking 17 as happy from 1379 to 1394 has been MAINTAINED!
#
# Sample ID: 129
# Col: m1, DTW distance: 1.6949777573281843, expected limit: 30
# Col: m3, DTW distance: 1.5517579398526478, expected limit: 25
# Col: m12, DTW distance: 1.388157142482347, expected limit: 15
# Col: e2, DTW distance: 4.651035382161017, expected limit: 20
# Seed 40 marking 18 as happy from 1089 to 1110 has been MAINTAINED!
#
# Sample ID: 130
# Col: m1, DTW distance: 3.681851289926904, expected limit: 30
# Col: m3, DTW distance: 2.139334586574512, expected limit: 25
# Col: m12, DTW distance: 2.0072088776433326, expected limit: 15
# Col: e2, DTW distance: 3.1370962948885137, expected limit: 20
# Seed 21 marking 18 as happy from 1139 to 1165 has been MAINTAINED!
#
# Sample ID: 131
# Col: m1, DTW distance: 1.4894698308484606, expected limit: 30
# Col: m3, DTW distance: 0.9980487003622918, expected limit: 25
# Col: m12, DTW distance: 0.5310931228783415, expected limit: 15
# Col: e2, DTW distance: 1.873990083819706, expected limit: 20
# Seed 37 marking 18 as happy from 1195 to 1204 has been MAINTAINED!
#
# Sample ID: 132
# Col: m1, DTW distance: 4.114802539958558, expected limit: 30
# Col: m3, DTW distance: 1.1324977992336083, expected limit: 25
# Col: m12, DTW distance: 0.821792389969242, expected limit: 15
# Col: e2, DTW distance: 1.799308568271558, expected limit: 20
# Seed 37 marking 18 as happy from 1578 to 1587 has been MAINTAINED!
#
# Sample ID: 133
# Col: m1, DTW distance: 3.6128209349607587, expected limit: 30
# Col: m3, DTW distance: 1.6978328568010814, expected limit: 25
# Col: m12, DTW distance: 3.363211241046597, expected limit: 15
# Col: e2, DTW distance: 2.401457917907301, expected limit: 20
# Seed 33 marking 19 as happy from 968 to 987 has been MAINTAINED!
#
# Sample ID: 134
# Col: m1, DTW distance: 1.3809197149644035, expected limit: 30
# Col: m3, DTW distance: 1.6287768153761204, expected limit: 25
# Col: m12, DTW distance: 2.1552307522281358, expected limit: 15
# Col: e2, DTW distance: 3.22299420570527, expected limit: 20
# Seed 44 marking 19 as happy from 1222 to 1236 has been MAINTAINED!
#
# Sample ID: 135
# Col: m1, DTW distance: 3.1755901195154483, expected limit: 30
# Col: m3, DTW distance: 1.576863577314203, expected limit: 25
# Col: m12, DTW distance: 1.4302946691116938, expected limit: 15
# Col: e2, DTW distance: 3.3186105797868555, expected limit: 20
# Seed 44 marking 19 as happy from 1372 to 1386 has been MAINTAINED!
#
# Sample ID: 136
# Col: m1, DTW distance: 2.6359775617563366, expected limit: 30
# Col: m3, DTW distance: 2.3539913757274413, expected limit: 25
# Col: m12, DTW distance: 1.5783566633995867, expected limit: 15
# Col: e2, DTW distance: 2.123395385345816, expected limit: 20
# Seed 23 marking 19 as happy from 3139 to 3158 has been MAINTAINED!
#
# Sample ID: 137
# Col: m1, DTW distance: 1.3457188695763274, expected limit: 30
# Col: m3, DTW distance: 1.1623122832579236, expected limit: 25
# Col: m12, DTW distance: 2.0477095949557853, expected limit: 15
# Col: e2, DTW distance: 3.180781716516547, expected limit: 20
# Seed 25 marking 19 as happy from 4126 to 4153 has been MAINTAINED!
#
# Sample ID: 138
# Col: m1, DTW distance: 5.932115659161626, expected limit: 30
# Col: m3, DTW distance: 2.6513795789111696, expected limit: 25
# Col: m12, DTW distance: 1.540832127878688, expected limit: 15
# Col: e2, DTW distance: 2.0864310397432027, expected limit: 20
# Seed 23 marking 19 as happy from 4524 to 4543 has been MAINTAINED!
#
# Sample ID: 139
# Col: m1, DTW distance: 0.6264010937193376, expected limit: 30
# Col: m3, DTW distance: 0.9691444646658511, expected limit: 25
# Col: m12, DTW distance: 0.7991354223672068, expected limit: 15
# Col: e2, DTW distance: 2.4305989431224444, expected limit: 20
# Seed 26 marking 19 as happy from 4862 to 4887 has been MAINTAINED!
#
# Sample ID: 140
# Col: m1, DTW distance: 2.5831003774844055, expected limit: 30
# Col: m3, DTW distance: 1.6700429571235045, expected limit: 25
# Col: m12, DTW distance: 3.592540479264209, expected limit: 15
# Col: e2, DTW distance: 3.0900700307278126, expected limit: 20
# Seed 20 marking 20 as happy from 30 to 51 has been MAINTAINED!
#
# Sample ID: 141
# Col: m1, DTW distance: 4.462107194921142, expected limit: 30
# Col: m3, DTW distance: 2.193191524111223, expected limit: 25
# Col: m12, DTW distance: 2.8584231064423955, expected limit: 15
# Col: e2, DTW distance: 2.811468809160892, expected limit: 20
# Seed 44 marking 21 as happy from 666 to 680 has been MAINTAINED!
#
# Sample ID: 142
# Col: m1, DTW distance: 4.184666573475278, expected limit: 30
# Col: m3, DTW distance: 1.503699497023432, expected limit: 25
# Col: m12, DTW distance: 2.4366260080999633, expected limit: 15
# Col: e2, DTW distance: 2.2672407560530776, expected limit: 20
# Seed 27 marking 21 as happy from 830 to 846 has been MAINTAINED!
#
# Sample ID: 143
# Col: m1, DTW distance: 1.9862789605838103, expected limit: 30
# Col: m3, DTW distance: 1.4093317147954607, expected limit: 25
# Col: m12, DTW distance: 2.47002465000032, expected limit: 15
# Col: e2, DTW distance: 3.3603624720708773, expected limit: 20
# Seed 17 marking 21 as happy from 1649 to 1667 has been MAINTAINED!
#
# Sample ID: 144
# Col: m1, DTW distance: 2.3417793464880985, expected limit: 30
# Col: m3, DTW distance: 1.735849122200374, expected limit: 25
# Col: m12, DTW distance: 1.2464272616338419, expected limit: 15
# Col: e2, DTW distance: 2.449847601109828, expected limit: 20
# Seed 36 marking 21 as happy from 3158 to 3172 has been MAINTAINED!
#
# Sample ID: 145
# Col: m1, DTW distance: 3.472330402552641, expected limit: 30
# Col: m3, DTW distance: 2.9867296768719847, expected limit: 25
# Col: m12, DTW distance: 2.229325908706041, expected limit: 15
# Col: e2, DTW distance: 3.069097758365039, expected limit: 20
# Seed 44 marking 21 as happy from 3858 to 3872 has been MAINTAINED!
#
# Sample ID: 146
# ...
# Col: m12, DTW distance: 3.032044194182188, expected limit: 15
# Col: e2, DTW distance: 2.970651261007833, expected limit: 20
# Seed 33 marking 30 as happy from 403 to 422 has been MAINTAINED!
#
# Sample ID: 285
# Col: m1, DTW distance: 3.5664048763278986, expected limit: 30
# Col: m3, DTW distance: 3.7722315793585453, expected limit: 25
# Col: m12, DTW distance: 2.3230410991145884, expected limit: 15
# Col: e2, DTW distance: 2.7152127183724546, expected limit: 20
# Seed 44 marking 30 as happy from 487 to 501 has been MAINTAINED!
#
# Sample ID: 286
# Col: m1, DTW distance: 6.232640016007274, expected limit: 30
# Col: m3, DTW distance: 4.20130543898933, expected limit: 25
# Col: m12, DTW distance: 3.247444909712092, expected limit: 15
# Col: e2, DTW distance: 2.9125964414580836, expected limit: 20
# Seed 25 marking 30 as happy from 706 to 733 has been MAINTAINED!
#
# Sample ID: 287
# Col: m1, DTW distance: 3.552598299666739, expected limit: 30
# Col: m3, DTW distance: 3.305944747374166, expected limit: 25
# Col: m12, DTW distance: 2.5523309839251835, expected limit: 15
# Col: e2, DTW distance: 2.891848907517128, expected limit: 20
# Seed 44 marking 30 as happy from 1870 to 1884 has been MAINTAINED!
#
# Sample ID: 288
# Col: m1, DTW distance: 3.454509232436804, expected limit: 30
# Col: m3, DTW distance: 1.6010415445037398, expected limit: 25
# Col: m12, DTW distance: 3.270616274275947, expected limit: 15
# Col: e2, DTW distance: 1.2750456640364263, expected limit: 20
# Seed 29 marking 30 as happy from 2233 to 2244 has been MAINTAINED!
#
# Sample ID: 289
# Col: m1, DTW distance: 3.682488763867509, expected limit: 30
# Col: m3, DTW distance: 3.6193041379978483, expected limit: 25
# Col: m12, DTW distance: 2.823443648242477, expected limit: 15
# Col: e2, DTW distance: 2.6576206344390623, expected limit: 20
# Seed 44 marking 31 as happy from 200 to 214 has been MAINTAINED!
#
# Sample ID: 290
# Col: m1, DTW distance: 4.868012123852162, expected limit: 30
# Col: m3, DTW distance: 1.977376146606446, expected limit: 25
# Col: m12, DTW distance: 1.163145085080122, expected limit: 15
# Col: e2, DTW distance: 2.8289436084400643, expected limit: 20
# Seed 18 marking 31 as happy from 548 to 575 has been MAINTAINED!
#
# Sample ID: 291
# Col: m1, DTW distance: 2.063853584716196, expected limit: 30
# Col: m3, DTW distance: 0.7075030080190905, expected limit: 25
# Col: m12, DTW distance: 0.7366990548681617, expected limit: 15
# Col: e2, DTW distance: 2.6593534768969858, expected limit: 20
# Seed 19 marking 31 as happy from 1213 to 1226 has been MAINTAINED!
#
# Sample ID: 292
# Col: m1, DTW distance: 8.516115639703655, expected limit: 30
# Col: m3, DTW distance: 2.0610580883110816, expected limit: 25
# Col: m12, DTW distance: 2.4542197152542213, expected limit: 15
# Col: e2, DTW distance: 3.7445516023896417, expected limit: 20
# Seed 25 marking 31 as happy from 1374 to 1401 has been MAINTAINED!
#
# Sample ID: 293
# Col: m1, DTW distance: 1.5705102605876076, expected limit: 30
# Col: m3, DTW distance: 1.0497260451921955, expected limit: 25
# Col: m12, DTW distance: 1.1062187996804178, expected limit: 15
# Col: e2, DTW distance: 2.5274512223971826, expected limit: 20
# Seed 45 marking 31 as happy from 2604 to 2615 has been MAINTAINED!
#
# Sample ID: 294
# Col: m1, DTW distance: 1.5124070441941686, expected limit: 30
# Col: m3, DTW distance: 2.0909051608631373, expected limit: 25
# Col: m12, DTW distance: 2.019781399910818, expected limit: 15
# Col: e2, DTW distance: 1.9315419948661292, expected limit: 20
# Seed 23 marking 31 as happy from 3620 to 3639 has been MAINTAINED!
#
# Sample ID: 295
# Col: m1, DTW distance: 2.81984317959869, expected limit: 30
# Col: m3, DTW distance: 2.4310588456797513, expected limit: 25
# Col: m12, DTW distance: 2.253275317287237, expected limit: 15
# Col: e2, DTW distance: 2.7453035188228343, expected limit: 20
# Seed 44 marking 31 as happy from 3818 to 3832 has been MAINTAINED!
#
# Sample ID: 296
# Col: m1, DTW distance: 4.5075203444062435, expected limit: 30
# Col: m3, DTW distance: 1.5658458779188882, expected limit: 25
# Col: m12, DTW distance: 2.0634803191707154, expected limit: 15
# Col: e2, DTW distance: 1.699240980188238, expected limit: 20
# Seed 22 marking 31 as happy from 5662 to 5686 has been MAINTAINED!
#
# Sample ID: 297
# Col: m1, DTW distance: 3.454087901013048, expected limit: 30
# Col: m3, DTW distance: 1.4345969430773702, expected limit: 25
# Col: m12, DTW distance: 1.1111465866585428, expected limit: 15
# Col: e2, DTW distance: 4.591262217167838, expected limit: 20
# Seed 26 marking 32 as happy from 690 to 715 has been MAINTAINED!
#
# Sample ID: 298
# Col: m1, DTW distance: 4.5672680255286275, expected limit: 30
# Col: m3, DTW distance: 1.324886493894869, expected limit: 25
# Col: m12, DTW distance: 1.6128833256818118, expected limit: 15
# Col: e2, DTW distance: 2.4836211442559484, expected limit: 20
# Seed 18 marking 33 as happy from 639 to 661 has been MAINTAINED!
#
# Sample ID: 299
# Col: m1, DTW distance: 2.3467670906306397, expected limit: 30
# Col: m3, DTW distance: 2.5329947630349725, expected limit: 25
# Col: m12, DTW distance: 4.537467253635263, expected limit: 15
# Col: e2, DTW distance: 3.1482087171521003, expected limit: 20
# Seed 33 marking 33 as happy from 1287 to 1306 has been MAINTAINED!
#
# Sample ID: 300
# Col: m1, DTW distance: 4.327539708562657, expected limit: 30
# Col: m3, DTW distance: 1.1330511925991376, expected limit: 25
# Col: m12, DTW distance: 3.1686461687159904, expected limit: 15
# Col: e2, DTW distance: 2.8381575545283, expected limit: 20
# Seed 42 marking 33 as happy from 1394 to 1410 has been MAINTAINED!
#
# Sample ID: 301
# Col: m1, DTW distance: 1.2655679273579272, expected limit: 30
# Col: m3, DTW distance: 2.548641282118907, expected limit: 25
# Col: m12, DTW distance: 2.726897587278393, expected limit: 15
# Col: e2, DTW distance: 2.585805211824067, expected limit: 20
# Seed 44 marking 35 as happy from 273 to 287 has been MAINTAINED!
#
# Sample ID: 302
# Col: m1, DTW distance: 2.279315210894835, expected limit: 30
# Col: m3, DTW distance: 1.7249886384015827, expected limit: 25
# Col: m12, DTW distance: 3.419732398721278, expected limit: 15
# Col: e2, DTW distance: 2.90076963830306, expected limit: 20
# Seed 33 marking 35 as happy from 611 to 630 has been MAINTAINED!
#
# Sample ID: 303
# Col: m1, DTW distance: 1.333124484896543, expected limit: 30
# Col: m3, DTW distance: 1.0822747347516004, expected limit: 25
# Col: m12, DTW distance: 1.1864295330834682, expected limit: 15
# Col: e2, DTW distance: 2.9608135361959373, expected limit: 20
# Seed 40 marking 35 as happy from 2310 to 2331 has been MAINTAINED!
#
# Sample ID: 304
# Col: m1, DTW distance: 0.9950886689588052, expected limit: 30
# Col: m3, DTW distance: 1.3632088860837468, expected limit: 25
# Col: m12, DTW distance: 1.7863299450342824, expected limit: 15
# Col: e2, DTW distance: 2.5162579590419663, expected limit: 20
# Seed 41 marking 35 as happy from 2347 to 2371 has been MAINTAINED!
#
# Sample ID: 305
# Col: m1, DTW distance: 2.553060009141276, expected limit: 30
# Col: m3, DTW distance: 2.7078400841951265, expected limit: 25
# Col: m12, DTW distance: 1.888005944382957, expected limit: 15
# Col: e2, DTW distance: 1.1820310750348693, expected limit: 20
# Seed 29 marking 36 as happy from 7 to 18 has been MAINTAINED!
#
# Sample ID: 306
# Col: m1, DTW distance: 5.378971998475583, expected limit: 30
# Col: m3, DTW distance: 2.463219584093275, expected limit: 25
# Col: m12, DTW distance: 3.109832361728494, expected limit: 15
# Col: e2, DTW distance: 1.1446875551777582, expected limit: 20
# Seed 30 marking 36 as happy from 646 to 661 has been MAINTAINED!
#
# Sample ID: 307
# Col: m1, DTW distance: 3.955270959972714, expected limit: 30
# Col: m3, DTW distance: 1.5188182606592022, expected limit: 25
# Col: m12, DTW distance: 1.733259793726442, expected limit: 15
# Col: e2, DTW distance: 1.7547795516639761, expected limit: 20
# Seed 34 marking 36 as happy from 687 to 700 has been MAINTAINED!
#
# Sample ID: 308
# Col: m1, DTW distance: 4.022523825519295, expected limit: 30
# Col: m3, DTW distance: 1.8239213282856332, expected limit: 25
# Col: m12, DTW distance: 4.073670258703144, expected limit: 15
# Col: e2, DTW distance: 1.9205816030830756, expected limit: 20
# Seed 22 marking 36 as happy from 867 to 891 has been MAINTAINED!
#
# Sample ID: 309
# Col: m1, DTW distance: 4.364506449506801, expected limit: 30
# Col: m3, DTW distance: 1.6688113468721435, expected limit: 25
# Col: m12, DTW distance: 2.304420857297818, expected limit: 15
# Col: e2, DTW distance: 2.911401287030815, expected limit: 20
# Seed 44 marking 36 as happy from 927 to 941 has been MAINTAINED!
#
# Sample ID: 310
# Col: m1, DTW distance: 3.2324212001518853, expected limit: 30
# Col: m3, DTW distance: 2.9321378914362257, expected limit: 25
# Col: m12, DTW distance: 2.509334082527682, expected limit: 15
# Col: e2, DTW distance: 3.523947373156016, expected limit: 20
# Seed 16 marking 36 as happy from 2101 to 2121 has been MAINTAINED!
#
# Sample ID: 311
# Col: m1, DTW distance: 5.302881246270624, expected limit: 30
# Col: m3, DTW distance: 1.3544454925328018, expected limit: 25
# Col: m12, DTW distance: 2.3416573243041077, expected limit: 15
# Col: e2, DTW distance: 1.64266143420205, expected limit: 20
# Seed 24 marking 36 as happy from 2433 to 2449 has been MAINTAINED!
#
# Sample ID: 312
# Col: m1, DTW distance: 4.688843277953625, expected limit: 30
# Col: m3, DTW distance: 0.9231618618275726, expected limit: 25
# Col: m12, DTW distance: 1.694184568281663, expected limit: 15
# Col: e2, DTW distance: 2.087452404270376, expected limit: 20
# Seed 24 marking 37 as happy from 2596 to 2612 has been MAINTAINED!
#
# Sample ID: 313
# Col: m1, DTW distance: 2.942109348878737, expected limit: 30
# Col: m3, DTW distance: 1.5849012291678533, expected limit: 25
# Col: m12, DTW distance: 2.3476342731808093, expected limit: 15
# Col: e2, DTW distance: 3.340034749326778, expected limit: 20
# Seed 33 marking 37 as happy from 3183 to 3202 has been MAINTAINED!
#
# Sample ID: 314
# Col: m1, DTW distance: 3.623737493015512, expected limit: 30
# Col: m3, DTW distance: 2.562428427527083, expected limit: 25
# Col: m12, DTW distance: 2.5369035794700188, expected limit: 15
# Col: e2, DTW distance: 2.4235963575076602, expected limit: 20
# Seed 23 marking 37 as happy from 3254 to 3273 has been MAINTAINED!
#
# Sample ID: 315
# Col: m1, DTW distance: 5.33563769303751, expected limit: 30
# Col: m3, DTW distance: 1.569842740514542, expected limit: 25
# Col: m12, DTW distance: 5.977759915671332, expected limit: 15
# Col: e2, DTW distance: 4.090841984010806, expected limit: 20
# Seed 33 marking 37 as happy from 3379 to 3398 has been MAINTAINED!
#
# Sample ID: 316
# Col: m1, DTW distance: 2.744589997762071, expected limit: 30
# Col: m3, DTW distance: 1.5247294080403448, expected limit: 25
# Col: m12, DTW distance: 2.939689061913132, expected limit: 15
# Col: e2, DTW distance: 3.02580916300508, expected limit: 20
# Seed 33 marking 37 as happy from 3875 to 3894 has been MAINTAINED!
#
# Sample ID: 317
# Col: m1, DTW distance: 6.413580779599708, expected limit: 30
# Col: m3, DTW distance: 3.1732449405185936, expected limit: 25
# Col: m12, DTW distance: 0.8040428220368533, expected limit: 15
# Col: e2, DTW distance: 1.5746802924676182, expected limit: 20
# Seed 18 marking 38 as happy from 29 to 51 has been MAINTAINED!
#
# Sample ID: 318
# Col: m1, DTW distance: 4.618182600711704, expected limit: 30
# Col: m3, DTW distance: 1.9965376502355894, expected limit: 25
# Col: m12, DTW distance: 1.8333349985409597, expected limit: 15
# Col: e2, DTW distance: 1.1043768600192498, expected limit: 20
# Seed 30 marking 38 as happy from 377 to 392 has been MAINTAINED!
#
# Sample ID: 319
# Col: m1, DTW distance: 2.0680555241298846, expected limit: 30
# Col: m3, DTW distance: 1.2061583396324134, expected limit: 25
# Col: m12, DTW distance: 1.57939002192749, expected limit: 15
# Col: e2, DTW distance: 2.359280465250101, expected limit: 20
# Seed 30 marking 38 as happy from 490 to 505 has been MAINTAINED!
#
# Sample ID: 320
# Col: m1, DTW distance: 2.6747113084329293, expected limit: 30
# Col: m3, DTW distance: 1.2585191292433218, expected limit: 25
# Col: m12, DTW distance: 1.019676876899564, expected limit: 15
# Col: e2, DTW distance: 3.216292983318153, expected limit: 20
# Seed 34 marking 38 as happy from 3344 to 3357 has been MAINTAINED!
#
# Sample ID: 321
# Col: m1, DTW distance: 3.6518826337991963, expected limit: 30
# Col: m3, DTW distance: 1.5878360256830546, expected limit: 25
# Col: m12, DTW distance: 1.5219117573415823, expected limit: 15
# Col: e2, DTW distance: 2.142644916555184, expected limit: 20
# Seed 18 marking 38 as happy from 3486 to 3508 has been MAINTAINED!
#
# Sample ID: 322
# Col: m1, DTW distance: 1.9778888841171085, expected limit: 30
# Col: m3, DTW distance: 2.5545320070287993, expected limit: 25
# Col: m12, DTW distance: 1.3819278512819644, expected limit: 15
# Col: e2, DTW distance: 2.2335534473670275, expected limit: 20
# Seed 38 marking 38 as happy from 3547 to 3557 has been MAINTAINED!
#
# Sample ID: 323
# Col: m1, DTW distance: 2.7023852446351753, expected limit: 30
# Col: m3, DTW distance: 1.1167907326426239, expected limit: 25
# Col: m12, DTW distance: 1.64730246583611, expected limit: 15
# Col: e2, DTW distance: 1.08575383335331, expected limit: 20
# Seed 29 marking 38 as happy from 3729 to 3740 has been MAINTAINED!
#
# Sample ID: 324
# Col: m1, DTW distance: 6.346382961683098, expected limit: 30
# Col: m3, DTW distance: 2.0609221762132197, expected limit: 25
# Col: m12, DTW distance: 2.174114436034544, expected limit: 15
# Col: e2, DTW distance: 2.6945780337688454, expected limit: 20
# Seed 44 marking 38 as happy from 4732 to 4746 has been MAINTAINED!
#
# Sample ID: 325
# Col: m1, DTW distance: 1.9048398516779483, expected limit: 30
# Col: m3, DTW distance: 1.5812769340577097, expected limit: 25
# Col: m12, DTW distance: 0.8315475822877875, expected limit: 15
# Col: e2, DTW distance: 2.4490437978065973, expected limit: 20
# Seed 37 marking 38 as happy from 5780 to 5789 has been MAINTAINED!
#
# Sample ID: 326
# Col: m1, DTW distance: 3.8069642025164323, expected limit: 30
# Col: m3, DTW distance: 6.915529205161084, expected limit: 25
# Col: m12, DTW distance: 3.5408631698507707, expected limit: 15
# Col: e2, DTW distance: 2.6445412340314496, expected limit: 20
# Seed 44 marking 38 as happy from 5882 to 5896 has been MAINTAINED!
#
# Sample ID: 327
# Col: m1, DTW distance: 4.069495498804634, expected limit: 30
# Col: m3, DTW distance: 1.8459522729008637, expected limit: 25
# Col: m12, DTW distance: 1.8745116863010114, expected limit: 15
# Col: e2, DTW distance: 3.1110216469563783, expected limit: 20
# Seed 35 marking 38 as happy from 6102 to 6123 has been MAINTAINED!
#
# Sample ID: 328
# Col: m1, DTW distance: 1.5581329472987357, expected limit: 30
# Col: m3, DTW distance: 1.1613828689120669, expected limit: 25
# Col: m12, DTW distance: 2.7944945003244763, expected limit: 15
# Col: e2, DTW distance: 3.062005382154113, expected limit: 20
# Seed 33 marking 39 as happy from 59 to 78 has been MAINTAINED!
#
# Sample ID: 329
# Col: m1, DTW distance: 3.7164427605200876, expected limit: 30
# Col: m3, DTW distance: 1.5424753901404697, expected limit: 25
# Col: m12, DTW distance: 1.6845824345536948, expected limit: 15
# Col: e2, DTW distance: 3.285884311032249, expected limit: 20
# Seed 18 marking 39 as happy from 919 to 941 has been MAINTAINED!
#
# Sample ID: 330
# Col: m1, DTW distance: 1.2419288193131197, expected limit: 30
# Col: m3, DTW distance: 1.3974421544373257, expected limit: 25
# Col: m12, DTW distance: 2.934951973909746, expected limit: 15
# Col: e2, DTW distance: 1.6971817421965998, expected limit: 20
# Seed 38 marking 39 as happy from 1298 to 1308 has been MAINTAINED!
#
# Sample ID: 331
# Col: m1, DTW distance: 2.7548714632625866, expected limit: 30
# Col: m3, DTW distance: 1.3569819110294568, expected limit: 25
# Col: m12, DTW distance: 4.776702289326025, expected limit: 15
# Col: e2, DTW distance: 2.941959143109312, expected limit: 20
# Seed 33 marking 41 as happy from 629 to 648 has been MAINTAINED!
#
# Sample ID: 332
# Col: m1, DTW distance: 1.209557280591574, expected limit: 30
# Col: m3, DTW distance: 0.7758741756480655, expected limit: 25
# Col: m12, DTW distance: 1.2315396063038067, expected limit: 15
# Col: e2, DTW distance: 2.0334176532549444, expected limit: 20
# Seed 29 marking 42 as happy from 227 to 238 has been MAINTAINED!

# %%
smile_data = [emotion for emotion in new_grouped_data if emotion[5] == 'happy']
print(len(new_grouped_data))
# Out:
# 333

# %%
build_new_filtered_sequence_dataset(new_grouped_data, columns)
# Out:
# Dataset saved to result_sequences/filtered_sequences_17_m1_30_m3_25_m12_15_e2_20.CSV
